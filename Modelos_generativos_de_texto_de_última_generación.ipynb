# %% [markdown]
# XLNet
#
# GPT-2
#
# text generation
#
# fine-tuning (e.g., game of thrones)
#
# question answering
#
# translation
#
# --see if it is possible to do without spitting out so much crap and using text files as input and output

# %% [markdown]
# #XLNet

# %%
# !git clone https://github.com/rusiaaman/XLnet-gen.git
# %cd XLnet-gen
#!pip install -r requirements.txt
# !wget https://storage.googleapis.com/xlnet/released_models/cased_L-24_H-1024_A-16.zip
# !unzip cased_L-24_H-1024_A-16.zip
# Out:
# Cloning into 'XLnet-gen'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 175 (delta 96), reused 111 (delta 48), pack-reused 0
# Receiving objects: 100% (175/175), 202.71 KiB | 902.00 KiB/s, done.
# Resolving deltas: 100% (96/96), done.
# /content/XLnet-gen
# --2019-07-01 08:13:14--  https://storage.googleapis.com/xlnet/released_models/cased_L-24_H-1024_A-16.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.126.128, 2a00:1450:4013:c03::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.126.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1338042341 (1.2G) [application/zip]
# Saving to: ‘cased_L-24_H-1024_A-16.zip’
#
# cased_L-24_H-1024_A 100%[===================>]   1.25G   130MB/s    in 8.2s
#
# 2019-07-01 08:13:22 (156 MB/s) - ‘cased_L-24_H-1024_A-16.zip’ saved [1338042341/1338042341]
#
# ...

# %%
# !python language_generation.py\
     --model_config_path=xlnet_cased_L-24_H-1024_A-16/xlnet_config.json\
     --init_checkpoint=xlnet_cased_L-24_H-1024_A-16/xlnet_model.ckpt\
     --spiece_model_file=xlnet_cased_L-24_H-1024_A-16/spiece.model\
     --interactive\
     --max_mem_length 512\
     --num_toks_pred=512\
     --num_samples=1\
     --top_p=0.9
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0701 08:13:47.109874 139769898252160 deprecation_wrapper.py:119] From /content/XLnet-gen/model_utils.py:292: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Args: {'model_config_path': 'xlnet_cased_L-24_H-1024_A-16/xlnet_config.json', 'clamp_len': -1, 'same_length': False, 'batch_size': 1, 'max_mem_length': 512, 'uncased': False, 'init_checkpoint': 'xlnet_cased_L-24_H-1024_A-16/xlnet_model.ckpt', 'spiece_model_file': 'xlnet_cased_L-24_H-1024_A-16/spiece.model', 'input_file': '', 'num_samples': 1, 'interactive': True, 'unconditional': False, 'top_p': 0.9, 'top_k': 40, 'temperature': 1, 'num_toks_pred': 512, 'autoregressive': False, 'use_tpu': False, 'use_bfloat16': False, 'dropout': 0, 'dropatt': 0, 'init': 'normal', 'init_std': 0.02, 'init_range': 0.1}
# ...

# %% [markdown]
# #GPT-2

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/nshepperd/gpt-2.git
# %cd gpt-2
# !pip3 install -r requirements.txt
# !mkdir '/content/drive/My Drive/Colab Notebooks/run1'
# !sed -i "s+'checkpoint'+'/content/drive/My Drive/Colab Notebooks'+g" train.py

# %%
# !python3 download_model.py 345M

# %%
# !export PYTHONIOENCODING=UTF-8
# !wget -O train.txt 'https://docs.google.com/uc?export=download&id=1yQgoz5QmvbxQzN2TZWWjvniPqDhGoC8W'
# !PYTHONPATH=src ./train.py --dataset /content/gpt-2/train.txt --model_name '345M'
# !cp -r '/content/drive/My Drive/Colab Notebooks/run1/*' /content/gpt-2/models/345M/

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/run1/*' /content/gpt-2/models/345M/

# %%
# !python3 src/interactive_conditional_samples.py --top_k 40 --model_name "345M"
