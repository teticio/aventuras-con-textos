# %% [markdown]
# <a href="https://colab.research.google.com/github/teticio/aventuras-en-texto/blob/master/Modelos_generativos_de_texto_de_%C3%BAltima_generaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importar librerías

# %%
import os
import sys
import selectors
import subprocess as sp
from IPython.display import clear_output
from IPython.core.display import display, HTML
import json
import numpy as np
import tensorflow as tf

sess = tf.Session()

# %% [markdown]
# # XLNet

# %% [markdown]
# ### Instalar modelo

# %%
# !test -d XLnet-gen || git clone --quiet https://github.com/rusiaaman/XLnet-gen.git
# !pip install -q -r XLnet-gen/requirements.txt
# !test -e cased_L-24_H-1024_A-16.zip || wget -q https://storage.googleapis.com/xlnet/released_models/cased_L-24_H-1024_A-16.zip
# !test -d xlnet_cased_L-24_H-1024_A-16 || unzip -q cased_L-24_H-1024_A-16.zip
# Out:
#      |████████████████████████████████| 1.0MB 6.7MB/s
#      |████████████████████████████████| 51kB 19.7MB/s

# %% [markdown]
# ### Generar texto

# %%
ejemplo = 'Sadly, however, before she could get to a phone to tell anyone- about it, a terribly stupid catastrophe occurred, and the idea was lost forever.' #@param {type : 'string'}
with open('test', 'wt') as file:
    file.write(ejemplo)
command = ['python', 'XLnet-gen/language_generation.py',
           '--model_config_path=xlnet_cased_L-24_H-1024_A-16/xlnet_config.json',
           '--init_checkpoint=xlnet_cased_L-24_H-1024_A-16/xlnet_model.ckpt',
           '--spiece_model_file=xlnet_cased_L-24_H-1024_A-16/spiece.model',
           '--input_file=test',
           '--max_mem_length=512',
           '--num_toks_pred=512',
           '--num_samples=1',
           '--top_p=0.9']
p = sp.Popen(command, stderr=sp.PIPE)
if p.returncode != 0:
    print(p.communicate()[1].decode())
with open('test.xlnet', 'rt') as file:
    for line in file.readlines():
        display(HTML('<p>' + line + '</p>'))
# Out:
# <p>
# </p>
# <p>======Example 0=================
# </p>
# <p>Sadly, however, before she could get to a phone to tell anyone- about it, a terribly stupid catastrophe occurred, and the idea was lost forever.
# </p>
# <p>======Example 0 SAMPLE 0======
# </p>
# <p>Now she was stuck with the dreadful notion of seeing herself impure and not even knowing what she had imagined. Sure, it was only a whiff of impure air she had been breathing for that whole time, but what could she have actually imagined? She had no idea how to think of anything.
# </p>
# <p>
# </p>
# <p>After everyone had spoken, she turned to take the stairs down to her apartment and watched the people leave. The crowd were already in a hurry to get out of the restaurant. Since she was alone, she thought she would try to a lie. With each successive thing she wanted to tell people, she found it hard to think of a lie.
# </p>
# <p>
# </p>
# <p>A big pro at lying like her father was, she needed to think of something else that would have an easy target in the eyes of those around her. After all, this was her last chance to tell her father about her friend and everyone else about her boyfriend and the wedding plans they had on the horizon. At the moment, it was more important to avoid things than face her fears.
# </p>
# <p>
# </p>
# <p>For that reason, she started to think about something else. Possibly something that would involve going to a dungeon, torture, or some other horrible horrible thing that would hurt her. It would also need to be intimate with people, which her father would probably be very uncomfortable with. When she thought about the possibility, she was appalled by how terribly destructive and scary it all could be.
# </p>
# <p>
# </p>
# <p>Next, she thought about another rather horrible idea that was "on the thoughts" of the other people in the restaurant. These men were already together. She decided it would be easy for them to discover that there were two women in the party, and take their chances with them. She knew she could prevent this. In fact, she was preparing herself mentally to use her abilities to prevent it. If anything, it might also make things even more difficult for her dad.
# </p>
# <p>
# </p>
# <p>She thought about how hard it was not to see herself in the same light as the woman who had been in the photo. In fact, it was hard to imagine the woman as the person who had been in the photo, because she had no idea what it would be like. It seemed much more difficult than she had thought it would be.
# </p>
# <p>
# </p>
# <p>She had to have some kind of defense for herself. If anyone did discover that she was a female, it would mean a lot to her father. The thought of that made her want to scream, but the words didn't come easily to her. They didn't come
# </p>
# <p>==================================
# </p>

# %% [markdown]
# # GPT-2

# %% [markdown]
# ### Instalar el modelo

# %%
# !test -d gpt-2 || git clone --quiet https://github.com/nshepperd/gpt-2.git
# !pip install -q -r gpt-2/requirements.txt
# Out:
#      |████████████████████████████████| 604kB 14.0MB/s
#      |████████████████████████████████| 51kB 17.2MB/s
#   Building wheel for fire (setup.py) ... done
#   Building wheel for regex (setup.py) ... done

# %% [markdown]
# ### Descargar los pesos del modelo pre-entrenado

# %%
if not os.path.exists('gpt-2/models/345M'):
    sp.call(['python', 'download_model.py', '345M'], cwd='gpt-2')

# %% [markdown]
# ### Definir la función para generar textos
#
# Basado en https://github.com/openai/gpt-2/blob/master/src/interactive_conditional_samples.py

# %%
if not 'gpt-2/src' in sys.path: # hack
    sys.path += ['gpt-2/src']
import model, sample, encoder

def interact_model(
    prompt,
    model_name='117M',
    seed=None,
    nsamples=1,
    batch_size=1,
    length=None,
    temperature=1,
    top_k=0,
    top_p=0.0
):
    """
    Interactively run the model
    :model_name=117M : String, which model to use
    :seed=None : Integer seed for random number generators, fix seed to reproduce
     results
    :nsamples=1 : Number of samples to return total
    :batch_size=1 : Number of batches (only affects speed/memory).  Must divide nsamples.
    :length=None : Number of tokens in generated text, if None (default), is
     determined by model hyperparameters
    :temperature=1 : Float value controlling randomness in boltzmann
     distribution. Lower temperature results in less random completions. As the
     temperature approaches zero, the model will become deterministic and
     repetitive. Higher temperature results in more random completions.
    :top_k=0 : Integer value controlling diversity. 1 means only 1 word is
     considered for each step (token), resulting in deterministic completions,
     while 40 means 40 words are considered at each step. 0 (default) is a
     special setting meaning no restrictions. 40 generally is a good value.
    :top_p=0.0 : Float value controlling diversity. Implements nucleus sampling,
     overriding top_k if set to a value > 0. A good setting is 0.9.
    """
    if batch_size is None:
        batch_size = 1
    assert nsamples % batch_size == 0

    cwd = os.getcwd()
    os.chdir(cwd + '/gpt-2') # hack
    raw_text = prompt
    texts = []
    
    try:
        enc = encoder.get_encoder(model_name)
        hparams = model.default_hparams()
        with open(os.path.join('models', model_name, 'hparams.json')) as f:
            hparams.override_from_dict(json.load(f))

        if length is None:
            length = hparams.n_ctx // 2
        elif length > hparams.n_ctx:
            raise ValueError("Can't get samples longer than window size: %s" % hparams.n_ctx)

        context = tf.placeholder(tf.int32, [batch_size, None])
        np.random.seed(seed)
        tf.set_random_seed(seed)
        output = sample.sample_sequence(
            hparams=hparams, length=length,
            context=context,
            batch_size=batch_size,
            temperature=temperature, top_k=top_k, top_p=top_p
        )

        saver = tf.train.Saver()
        ckpt = tf.train.latest_checkpoint(os.path.join('models', model_name))
        saver.restore(sess, ckpt)

        context_tokens = enc.encode(raw_text)
        generated = 0
        for _ in range(nsamples // batch_size):
            out = sess.run(output, feed_dict={
                context: [context_tokens for _ in range(batch_size)]
            })[:, len(context_tokens):]
            for i in range(batch_size):
                generated += 1
                texts += [enc.decode(out[i])]
                
    except:
        os.chdir(cwd)
        raise
    os.chdir(cwd)
    return texts
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0715 12:46:21.668393 140161076074368 deprecation_wrapper.py:119] From gpt-2/src/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.

# %% [markdown]
# ### Generar muestras con el modelo

# %%
ejemplo = "You're in a desert, walking along in the sand, when all of a sudden you look down and see a tortoise, Leon. It's crawling toward you. You reach down, you flip the tortoise over on its back. The tortoise lays on its back, its belly baking in the hot sun, beating its legs trying to turn itself over, but it can\u2019t, not without your help. But you\u2019re not helping. Why is that?" #@param {type : 'string'}
numero_de_muestras = 3 #@param {type : 'number'}
temperature=1 #@param {type : 'number'}
#@markdown La temperatura controla el grado de aleatoriedad (0 = determinista)
top_k=40 #@param {type : 'integer'}
#@markdown Número de tokens generados en cada paso. Cuanto mayor, más diverso (0 = sin restricciones, funciona bien con 40)
top_p=0.9 #@param {type : 'number'}
#@markdown Controla la diversidad. (0 = valor por defecto, funciona bien con 0.9)
texts = interact_model(prompt=ejemplo,
                       model_name='345M',
                       nsamples=numero_de_muestras,
                       temperature=temperature,
                       top_k=top_k,
                       top_p=top_p)
for i, text in enumerate(texts):
    display(HTML('<p>' + "=" * 40 + " SAMPLE " + str(i+1) + " " + "=" * 40 + '</p>'))
    display(HTML('<p>' + ('<b><i>' + ejemplo + '</b></i>' + text).replace('\n', '<br>') + '</p>'))
    display(HTML('<p>' + "=" * 80 + '</p>'))
    display(HTML('<p><br></p>'))
# Out:
# <p>======================================== SAMPLE 1 ========================================</p>
# <p><b><i>You're in a desert, walking along in the sand, when all of a sudden you look down and see a tortoise, Leon. It's crawling toward you. You reach down, you flip the tortoise over on its back. The tortoise lays on its back, its belly baking in the hot sun, beating its legs trying to turn itself over, but it can’t, not without your help. But you’re not helping. Why is that?</b></i>’ The tortoise is silent. It stares up at you.<br><br><br>For this, you apologize. You tell it to move on. You apologize again. The tortoise no longer can sit still. It moves on, dragging its leg.<br><br><br>It looks up. The tortoise looks up at you with a bright grin.<br><br><br>***<br><br><br>For days, the last images from one of my least favorite movies from my childhood are burned in my mind. I can't remember the title of the movie, as I could think of it at any moment. But the trailer comes out, and the whole world swells with shame. The movie exists, in my mind. Everything in the movie is an expression of my experiences. People I've known ask me why I thought those movies, and I'd tell them there's nothing wrong with them. Then, once they've done so, they can't remember what they were expecting.<br><br><br>I didn't even know for sure what was supposed to happen with the kids at the end. Many of my memories from that movie overlap in ways that make sense. But no matter what kids, students, or the "real" world watches, or doesn't see, they'll understand something about the movie.<br><br>Twenty years ago, the Academy of Motion Picture Arts and Sciences approved Shame, my first feature film. The parents were giving me a lot of grief for casting two white actors in blackface as human beggars. But for me, it was an honor and an adventure, a delight in the chase, ever closer to seeing people really feel for one another.<br><br><br>About the orgy-loving moon girl It is no accident that the film, screened for a student audience, was nominated for an Oscar. She is naked, she is shameless, but she is not only an attractive person. As she peels a pack of lemons and sacrifices them to insects like bats and scorpions, a detail that was only intended to provoke laughs, I recognized with joy that its tragic content was beautiful, even uplifting. "The End of the World as We Know It" is also a moment of transcendence. It is no accident that the movie, screened for a student audience, was nominated for an Oscar. She is naked, she is shameless, but she is not only an attractive person. As she peels a pack of lemons and sacrifices them to insects like bats and scorpions, a detail that was only intended to provoke laughs, I recognized with joy that its tragic</p>
# <p>================================================================================</p>
# <p><br></p>
# <p>======================================== SAMPLE 2 ========================================</p>
# <p><b><i>You're in a desert, walking along in the sand, when all of a sudden you look down and see a tortoise, Leon. It's crawling toward you. You reach down, you flip the tortoise over on its back. The tortoise lays on its back, its belly baking in the hot sun, beating its legs trying to turn itself over, but it can’t, not without your help. But you’re not helping. Why is that?</b></i> Is there something wrong’with you? Liger A You’are telling the truth. Hard enough that you have to take every breath out of it. Leon A It's your turn. Harder than you think. Harder than you're willing to go. You hold it. Liger A You. Hurry! Hurry, hurry’do not stop. Behind you’a beaver, a burrowing lizard, spots you. The burrowing lizard just as it was always kind enough to curl up in a ball next to you and stretch out an arm to shake your hand. Then it climbs up on its hind legs. Liger A It raises its right arm. It opens a small door over your shoulder. She turns the knob on the door to the room below. Three dead animals are scattered around, running through a ravine. Liger A More dead bodies, crawling through. There's blood everywhere. Then, like a train, something drops to the ground from above, throws back some body parts, and spills them all out over the place. Another little kid with a shirtless and stupid pose. The burrowing lizard. The burrowing lizard raises its right arm, takes out its fist, and goes for the butt. But Leon D turns around. Come back. Leon D Come back, coward! Liger A Do not try to beat them over the head, look down, and tell me you are fighting them, leaving them to die, it is better that than walking around surrounded by them? Big smile. "Good idea" makes you dizzy. Big smile, large slow smile, friend the burrowing lizard gets a drag and takes a bite out of his own butthole. Liger A Yes, it has laid down some zombie bodies and laid them out with all that dying away. He has killed quite a number of them, but that is more to attract the carnivorous insects that once ate their own. Big smile. "I will teach you to live", they say from beneath you. Leon D Oughta fuckin' bother’move out’or else! Liger A Do not. Leon D You are an alien. ’You’will’be going to another planet with monsters. So you understand not to bother, because it could just as well take you with it. I assume you know how far away this planet is, maybe a million kilometers. Liger A You've got a course? That's this planet's orbit. More than</p>
# <p>================================================================================</p>
# <p><br></p>
# <p>======================================== SAMPLE 3 ========================================</p>
# <p><b><i>You're in a desert, walking along in the sand, when all of a sudden you look down and see a tortoise, Leon. It's crawling toward you. You reach down, you flip the tortoise over on its back. The tortoise lays on its back, its belly baking in the hot sun, beating its legs trying to turn itself over, but it can’t, not without your help. But you’re not helping. Why is that?</b></i> Because ’I don't give a shit about a tortoise, I've been around for forty years and I've fought wars’ But, though Leon is wounded, you don't give a shit because ’I'm a coward, we need help, they're coming. They're crawling up the side of a hill, and out in the distance you see a red and blue and white patch’ And suddenly, you start running with Leon. I've seen tanks burn before, but this is hot’ But again, you run after them, running against the never ending dangers of the desert. You see a red, yellow and white rectangle ’this is the Death Star’ and suddenly, something terrible happens. A giant cylindrical object is burning through the sky. As you watch it burn, an explosion’ the blob of smoke ’clears the horizon as it floats up to us, a huge, blazing white globe’ charging towards us. And you watch it right behind you on that gigantic globe. You rush toward it, aim, blast. But not, because you don't care. You're watching the Death Star do one amazing thing, and now, the heroes’and the galaxy’are going down’<|endoftext|>People change, jobs change, progress stagnates. The topic of video game marketing, the platform that supposedly gave rise to entire forms of entertainment, seems and always has been relegated to the back of main headlines and unreported blogs. And if you're looking to game makers in particular, this is becoming a problem because there's still a bit of quality control to this idea that a publication that hopes to expand a market, is going to put their whole company at risk for another outlet to copy and paste to their liking, instead of producing something unique to their audience.<br><br>It's easy to get into this territory. Why should an animated RPG be your exclusive lifestyle knowledge, compared to the world of Minecraft or Portal? I've heard it's because game makers don't always know how to sell their product well enough to encourage the hardcore gamers that make the title popular, and are sometimes unable to convince people to spend a month or more just for that core multiplayer experience.<br><br><br>It's not that all game designers are nukers. Many are commercial designers of diverse styles and language tones who want to sell their designs across platforms, including still-useable games like Minecraft. If you want to compare your game design to a 5 year old game you did on two</p>
# <p>================================================================================</p>
# <p><br></p>

# %% [markdown]
# https://d4mucfpksywv.cloudfront.net/better-language-models/language_models_are_unsupervised_multitask_learners.pdf

# %% [markdown]
# ### Contestar una pregunta sobre un texto

# %%
contexto = 'The 2008 Summer Olympics torch relay was run from March 24 until August 8, 2008, prior to the 2008 Summer \n\
Olympics, with the theme of “one world, one dream”. Plans for the relay were announced on April 26, 2007, in \n\
Beijing, China. The relay, also called by the organizers as the “Journey of Harmony”, lasted 129 days and carried \n\
the torch 137,000 km (85,000 mi) – the longest distance of any Olympic torch relay since the tradition was started \n\
ahead of the 1936 Summer Olympics. \n\
\n\
After being lit at the birthplace of the Olympic Games in Olympia, Greece on March 24, the torch traveled to the \n\
Panathinaiko Stadium in Athens, and then to Beijing, arriving on March 31. From Beijing, the torch was \n\
following a route passing through six continents. The torch has visited cities along the Silk Road, symbolizing \n\
ancient links between China and the rest of the world. The relay also included an ascent with the flame to the top of \n\
Mount Everest on the border of Nepal and Tibet, China from the Chinese side, which was closed specially for the \n\
event. \n\
\n\
Q: What was the theme \n\
A: “one world, one dream”. \n\
Q: What was the length of the race? \n\
A: 137,000 km \n\
Q: Was it larger than previous ones? \n\
A: No \n\
Q: Where did the race begin? \n\
A: Olympia, Greece \n\
Q: Is there anything notable about that place? \n\
A: birthplace of Olympic Games \n\
Q: Where did they go after? \n\
A: Athens \n\
Q: How many days was the race? \n\
A: seven \n\
Q: Did they visit any notable landmarks? \n\
A: Panathinaiko Stadium \n'

pregunta = 'Q: And did they climb any mountains? \n\
A:'

display(HTML('<p>' + (contexto + '<b><i>' + pregunta + '</b></i>').replace('\n', '<br>') + '</p>'))
texts = interact_model(prompt=contexto + pregunta,model_name='345M', temperature=0.001)
answer = texts[0][:texts[0].find('Q')]
display(HTML('<p>' + answer + '</p>'))
# Out:
# <p>The 2008 Summer Olympics torch relay was run from March 24 until August 8, 2008, prior to the 2008 Summer <br>Olympics, with the theme of “one world, one dream”. Plans for the relay were announced on April 26, 2007, in <br>Beijing, China. The relay, also called by the organizers as the “Journey of Harmony”, lasted 129 days and carried <br>the torch 137,000 km (85,000 mi) – the longest distance of any Olympic torch relay since the tradition was started <br>ahead of the 1936 Summer Olympics. <br><br>After being lit at the birthplace of the Olympic Games in Olympia, Greece on March 24, the torch traveled to the <br>Panathinaiko Stadium in Athens, and then to Beijing, arriving on March 31. From Beijing, the torch was <br>following a route passing through six continents. The torch has visited cities along the Silk Road, symbolizing <br>ancient links between China and the rest of the world. The relay also included an ascent with the flame to the top of <br>Mount Everest on the border of Nepal and Tibet, China from the Chinese side, which was closed specially for the <br>event. <br><br>Q: What was the theme <br>A: “one world, one dream”. <br>Q: What was the length of the race? <br>A: 137,000 km <br>Q: Was it larger than previous ones? <br>A: No <br>Q: Where did the race begin? <br>A: Olympia, Greece <br>Q: Is there anything notable about that place? <br>A: birthplace of Olympic Games <br>Q: Where did they go after? <br>A: Athens <br>Q: How many days was the race? <br>A: seven <br>Q: Did they visit any notable landmarks? <br>A: Panathinaiko Stadium <br><b><i>Q: And did they climb any mountains? <br>A:</b></i></p>
# <p> Mount Everest
# </p>

# %%
contexto = 'Tom goes everywhere with Catherine Green, a 54-year-old secretary. He moves around her office at work and goes \n\
shopping with her. ”Most people don’t seem to mind Tom,” says Catherine, who thinks he is wonderful. ”He’s my \n\
fourth child,” she says. She may think of him and treat him that way as her son. He moves around buying his food, \n\
paying his health bills and his taxes, but in fact Tom is a dog. \n\
\n\
Catherine and Tom live in Sweden, a country where everyone is expected to lead an orderly life according to rules \n\
laid down by the government, which also provides a high level of care for its people. This level of care \n\
costs money. \n\
\n\
People in Sweden pay taxes on everything, so aren’t surprised to find that owning a dog means more \n\
taxes. Some people are paying as much as 500 Swedish kronor in taxes a year for the right to keep their dog, which \n\
is spent by the government on dog hospitals and sometimes medical treatment for a dog that falls ill. However, most \n\
such treatment is expensive, so owners often decide to offer health and even life for their dog. \n\
\n\
In Sweden dog owners must pay for any damage their dog does. A Swedish Kennel Club official explains what this means: \n\
if your dog runs out on the road and gets hit by a passing car, you, as the owner, have to pay \n\
for any damage done to the car, even if your dog has been killed in the accident. \n\
\n\
Q: How old is Catherine? \n\
A: 54 \n'

pregunta = 'Q: where does she live? \n\
A:'

display(HTML('<p>' + (contexto + '<b><i>' + pregunta + '</b></i>').replace('\n', '<br>') + '</p>'))
texts = interact_model(prompt=contexto + pregunta, model_name='345M', temperature=0.001)
answer = texts[0][:texts[0].find('Q')]
display(HTML('<p>' + answer + '</p>'))
# Out:
# <p>Tom goes everywhere with Catherine Green, a 54-year-old secretary. He moves around her office at work and goes <br>shopping with her. ”Most people don’t seem to mind Tom,” says Catherine, who thinks he is wonderful. ”He’s my <br>fourth child,” she says. She may think of him and treat him that way as her son. He moves around buying his food, <br>paying his health bills and his taxes, but in fact Tom is a dog. <br><br>Catherine and Tom live in Sweden, a country where everyone is expected to lead an orderly life according to rules <br>laid down by the government, which also provides a high level of care for its people. This level of care <br>costs money. <br><br>People in Sweden pay taxes on everything, so aren’t surprised to find that owning a dog means more <br>taxes. Some people are paying as much as 500 Swedish kronor in taxes a year for the right to keep their dog, which <br>is spent by the government on dog hospitals and sometimes medical treatment for a dog that falls ill. However, most <br>such treatment is expensive, so owners often decide to offer health and even life for their dog. <br><br>In Sweden dog owners must pay for any damage their dog does. A Swedish Kennel Club official explains what this means: <br>if your dog runs out on the road and gets hit by a passing car, you, as the owner, have to pay <br>for any damage done to the car, even if your dog has been killed in the accident. <br><br>Q: How old is Catherine? <br>A: 54 <br><b><i>Q: where does she live? <br>A:</b></i></p>
# <p> in Sweden. She lives in a small apartment in a small town in the north of Sweden. She is a single mother of two children. She is a member of the Swedish Kennel Club.
#
# </p>

# %% [markdown]
# ### Traducir una frase

# %%
# !test -e fra-eng.zip || wget -q https://www.manythings.org/anki/fra-eng.zip
# !test -e fra.txt || unzip -q fra-eng.zip

# %%
frases = []
with open('fra.txt', 'rt') as file:
    for line in file.readlines():
        tab = line.find('\t')
        frases += [line[:tab] + ' = ' + line[tab+1:]]
contexto = ''
for _ in np.random.choice(range(0, len(frases)), 100, replace=False):
    contexto += frases[_]
pregunta = 'What is your name? = '

display(HTML('<p>' + (contexto + '<b><i>' + pregunta + '</b></i>').replace('\n', '<br>') + '</p>'))
texts = interact_model(prompt=contexto + pregunta, model_name='345M', temperature=0.1)
answer = texts[0]
display(HTML('<p>' + answer + '</p>'))
# Out:
# <p>I made the best of my small room. = J'ai tiré le meilleur parti de ma petite chambre.<br>Not everyone is like you. = Tout le monde n'est pas comme toi.<br>She borrowed the book from him. = Elle lui emprunta le livre.<br>How about going to the movies on Saturday? = Ça te dirait d'aller voir un film samedi ?<br>Let's not talk about it. = Ne parlons pas de ça.<br>I'm seeing a friend tomorrow. = J'ai rendez-vous avec un ami demain.<br>I thought you'd be alone. = J'ai pensé que tu serais seule.<br>I've made a mistake, haven't I? = J'ai fait une erreur, non ?<br>I can't function without you. = Je n'arrive pas à fonctionner sans vous.<br>I'm not in the mood to do that now. = Je ne suis pas d'humeur à faire ça maintenant.<br>She could feel her knees shaking. = Elle pouvait sentir ses genoux trembler.<br>That makes perfect sense to me. = Ça me semble tomber sous le sens.<br>You can't park your car here. = Tu ne peux pas stationner ta voiture ici.<br>Tom took a bath last night. = Tom a pris un bain hier soir.<br>I'm going to ask you something. = Je vais vous demander quelque chose.<br>He's a junior employee. = C'est un employé subalterne.<br>You have a lot of nerve! = Tu as beaucoup de courage !<br>Tom doesn't still do that. = Tom ne le fait toujours pas.<br>Tom told the police everything he knew. = Tom a dit tout ce qu'il savait à la police.<br>His way of speaking offended me. = Sa manière de parler m'a offensée.<br>Websites collect information about you. = Les sites web rassemblent de l'information sur toi.<br>You're incredibly talented. = Tu es incroyablement talentueux.<br>These aren't words. = Ce ne sont pas des mots.<br>You will exist but you will never know what it is to live. = Tu existeras mais tu ne sauras jamais ce que c'est que de vivre.<br>I didn't know that Tom hated me. = Je ne savais pas que Tom me détestait.<br>He goes abroad every year. = Il se rend chaque année à l'étranger.<br>I'm about to have lunch. = Je suis sur le point de déjeuner.<br>You're not supposed to eat on the job. = Tu n'es pas supposé manger sur le lieu de travail.<br>These shoes are a little loose. = Ces chaussures sont un peu grandes.<br>Tom ate a gluten-free pretzel. = Tom a mangé un bretzel sans gluten.<br>A stranger is a friend you just haven't met yet. = Un étranger est un ami que vous n'avez simplement pas encore rencontré.<br>I cannot help wondering if he will come on time. = Je ne peux pas m'empêcher de me demander s'il viendra à l'heure.<br>Worrying never does you any good. = Se faire du souci ne fait jamais de bien.<br>We did fine. = Nous nous en sommes bien tirées.<br>I'm going out for a while. = Je sors un moment.<br>I can hardly imagine him going abroad. = J'arrive difficilement à l'imaginer en train de se rendre à l'étranger.<br>He cannot be trusted. = On ne peut pas se fier à lui.<br>Close the window before you leave. = Ferme la fenêtre avant de partir.<br>I saw Tom entering that restaurant. = J'ai vu Tom entrer dans ce restaurant.<br>We need to be prepared. = Il nous faut être préparées.<br>Things didn't turn out the way Tom expected. = Les choses n'ont pas pris la tournure à laquelle Tom s'attendait.<br>How about tonight? = Que dites-vous de cette nuit ?<br>Are they students? = Sont-ils étudiants ?<br>How do you explain all this? = Comment expliques-tu tout ceci ?<br>She admired him. = Elle l'admirait.<br>We talked to each other for a while. = Nous avons parlé un moment.<br>She was absent from school because she was sick. = Elle était absente à l'école car elle était malade.<br>More is not always better. = Davantage n'est pas toujours mieux.<br>I'm thorough. = Je suis minutieuse.<br>They're just rich kids. = Ce ne sont que des enfants riches.<br>He regrets his mistake. = Il regrette son erreur.<br>I wouldn't think of it. = Je n'y songerais pas.<br>Our fate was sealed. = Notre destinée était scellée.<br>I'm happy you two are friends again. = Je suis heureux que tous deux soyez à nouveau amis.<br>I can't believe I'm stuck here in thi ...
# <p>is.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  to be.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  to be.
#
#
#
#
#
#
#
#
#
#
#  to be.
#
#
#
#
#
#
#
#
#  to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to be to</p>

# %% [markdown]
# ### Resumir un texto

# %%
contexto ='1. Introduction \n\
\n\
Machine learning systems now excel (in expectation) at \n\
tasks they are trained for by using a combination of large \n\
datasets, high-capacity models, and supervised learning \n\
(Krizhevsky et al., 2012) (Sutskever et al., 2014) (Amodei \n\
et al., 2016). Yet these systems are brittle and sensitive to \n\
slight changes in the data distribution (Recht et al., 2018) \n\
and task specification (Kirkpatrick et al., 2017). Current \n\
systems are better characterized as narrow experts rather than \n\
competent generalists. We would like to move towards more \n\
general systems which can perform many tasks – eventually \n\
without the need to manually create and label a training \n\
dataset for each one. \n\
\n\
The dominant approach to creating ML systems is to collect a \n\
dataset of training examples demonstrating correct \n\
behavior for a desired task, train a system to imitate these \n\
behaviors, and then test its performance on independent \n\
and identically distributed (IID) held-out examples. This \n\
has served well to make progress on narrow experts. But \n\
the often erratic behavior of captioning models (Lake et al., \n\
2017), reading comprehension systems (Jia & Liang, 2017), \n\
and image classifiers (Alcorn et al., 2018) on the diversity \n\
and variety of possible inputs highlights some of the shortcomings \n\
of this approach. \n\
\n\
Our suspicion is that the prevalence of single task training \n\
on single domain datasets is a major contributor to the lack \n\
of generalization observed in current systems. Progress \n\
towards robust systems with current architectures is likely \n\
to require training and measuring performance on a wide \n\
range of domains and tasks. Recently, several benchmarks \n\
have been proposed such as GLUE (Wang et al., 2018) and \n\
decaNLP (McCann et al., 2018) to begin studying this. \n\
\n\
Multitask learning (Caruana, 1997) is a promising framework for \n\
improving general performance. However, multitask training in NLP \n\
is still nascent. Recent work reports modest performance \n\
improvements (Yogatama et al., \n\
2019) and the two most ambitious efforts to date have \n\
trained on a total of 10 and 17 (dataset, objective) \n\
pairs respectively (McCann et al., 2018) (Bowman et al., \n\
2018). From a meta-learning perspective, each (dataset, \n\
objective) pair is a single training example sampled \n\
from the distribution of datasets and objectives. Current \n\
ML systems need hundreds to thousands of examples to \n\
induce functions which generalize well. This suggests that \n\
multitask training many need just as many effective training \n\
pairs to realize its promise with current approaches. It will \n\
be very difficult to continue to scale the creation of datasets \n\
and the design of objectives to the degree that may be required  \n\
to brute force our way there with current techniques. \n\
This motivates exploring additional setups for performing \n\
multitask learning. \n'

pregunta = 'TL;DR:' # Too Long; Didn't Read (¡resúmelo por favor!)

display(HTML('<p>' + (contexto + '<b><i>' + pregunta + '</b></i>').replace('\n', '<br>') + '</p>'))
texts = interact_model(prompt=contexto + pregunta, model_name='345M', temperature=0.001)
answer = texts[0][:texts[0].find('.')+1]
display(HTML('<p>' + answer + '</p>'))
# Out:
# <p>1. Introduction <br><br>Machine learning systems now excel (in expectation) at <br>tasks they are trained for by using a combination of large <br>datasets, high-capacity models, and supervised learning <br>(Krizhevsky et al., 2012) (Sutskever et al., 2014) (Amodei <br>et al., 2016). Yet these systems are brittle and sensitive to <br>slight changes in the data distribution (Recht et al., 2018) <br>and task specification (Kirkpatrick et al., 2017). Current <br>systems are better characterized as narrow experts rather than <br>competent generalists. We would like to move towards more <br>general systems which can perform many tasks – eventually <br>without the need to manually create and label a training <br>dataset for each one. <br><br>The dominant approach to creating ML systems is to collect a <br>dataset of training examples demonstrating correct <br>behavior for a desired task, train a system to imitate these <br>behaviors, and then test its performance on independent <br>and identically distributed (IID) held-out examples. This <br>has served well to make progress on narrow experts. But <br>the often erratic behavior of captioning models (Lake et al., <br>2017), reading comprehension systems (Jia & Liang, 2017), <br>and image classifiers (Alcorn et al., 2018) on the diversity <br>and variety of possible inputs highlights some of the shortcomings <br>of this approach. <br><br>Our suspicion is that the prevalence of single task training <br>on single domain datasets is a major contributor to the lack <br>of generalization observed in current systems. Progress <br>towards robust systems with current architectures is likely <br>to require training and measuring performance on a wide <br>range of domains and tasks. Recently, several benchmarks <br>have been proposed such as GLUE (Wang et al., 2018) and <br>decaNLP (McCann et al., 2018) to begin studying this. <br><br>Multitask learning (Caruana, 1997) is a promising framework for <br>improving general performance. However, multitask training in NLP <br>is still nascent. Recent work reports modest performance <br>improvements (Yogatama et al., <br>2019) and the two most ambitious efforts to date have <br>trained on a total of 10 and 17 (dataset, objective) <br>pairs respectively (McCann et al., 2018) (Bowman et al., <br>2018). From a meta-learning perspective, each (dataset, <br>objective) pair is a single training example sampled <br>from the distribution of datasets and objectives. Current <br>ML systems need hundreds to thousands of examples to <br>induce functions which generalize well. This suggests that <br>multitask training many need just as many effective training <br>pairs to realize its promise with current approaches. It will <br>be very difficult to continue to scale the creation of datasets <br>and the design of objectives to the degree that may be required  <br>to brute force our way there with current techniques. <br>This motivates exploring additional setups for performing <br>multitask learning. <br><b><i>TL;DR:</b></i></p>
# <p> We propose a novel approach to training ML systems which
# allows for the creation of large datasets and large
# objectives.</p>

# %% [markdown]
# ### Descargar un texto para fine-tunear el modelo

# %%
# Game of Thrones: A Song of Fire and Ice
#!wget -q -O train.txt 'https://docs.google.com/uc?export=download&id=1RIWKr35ZAItxp7JH28Jp9JfqdqkllCrj'

# Cien Años de Soledad (no funciona muy bien al no haber sido entrenado en español el modelo...)
#!wget -q -O train.txt 'https://docs.google.com/uc?export=download&id=1XDJmGP9MtOLQSujO5Voicp1wyekHchpm'

# Harry Potter and the Goblet of Fire
# !wget -q -O train.txt 'https://docs.google.com/uc?export=download&id=1-A9slwS-AeH1bOOS8OVErLKDHyrlLrHk'

# %% [markdown]
# ### Crear directorio para guardar los checkpoints

# %%
checkpoint_dir = 'gpt-2/checkpoint'

try: # estamos en Google Colab?
    from google.colab import drive
    drive.mount('/content/drive')
    # como no hay parámetro, hay que usar la fuerza bruta para cambiar el directorio de los checkpoints
    # !sed -i "s+'checkpoint'+'/content/drive/My Drive/Colab Notebooks/checkpoints'+g" /content/gpt-2/train.py
    checkpoint_dir = '/content/drive/My Drive/Colab Notebooks/checkpoints/run1'
except:
    pass

try: # crear directorio para los checkpoints (si no exista ya)
    os.makedirs(checkpoint_dir)
except FileExistsError:
    pass
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Entrenar el modelo
#
# https://github.com/nshepperd/gpt-2.git

# %%
os.environ["PYTHONUNBUFFERED"] = "1"
os.environ['PYTHONIOENCODING'] = 'UTF-8'
os.environ['PYTHONPATH'] = 'src'
command = ['python', 'train.py', '--dataset=../train.txt', "--model_name", "345M"]
try:
    with sp.Popen(command, cwd='gpt-2', stdout=sp.PIPE, stderr=sp.PIPE) as p:
        sel = selectors.DefaultSelector()
        sel.register(p.stdout, selectors.EVENT_READ)
        sel.register(p.stderr, selectors.EVENT_READ)
        finished = False
        while not finished:
            finished = True
            for key, _ in sel.select():
                data = key.fileobj.readline().decode()
                if not data:
                    break
                finished = False
                if key.fileobj is p.stdout:
                    print(data, end="")
#                else:
#                    print(data, end="", file=sys.stderr)
                sys.stdout.flush()
except KeyboardInterrupt:
    p.terminate()
    raise
p.terminate()
# Out:
# Loading checkpoint /content/drive/My Drive/Colab Notebooks/checkpoints/run1/model-1000
# Loading dataset...
# dataset has 310044 tokens
# Training...
# [1001 | 11.99] loss=1.78 avg=1.78
# [1002 | 13.53] loss=1.18 avg=1.48
# [1003 | 15.07] loss=1.09 avg=1.35
# [1004 | 16.63] loss=1.53 avg=1.40
# [1005 | 18.17] loss=1.56 avg=1.43
# [1006 | 19.72] loss=1.65 avg=1.47
# [1007 | 21.28] loss=0.82 avg=1.37
# [1008 | 22.82] loss=2.23 avg=1.48
# [1009 | 24.38] loss=1.53 avg=1.49
# [1010 | 25.95] loss=1.68 avg=1.51
# [1011 | 27.52] loss=1.68 avg=1.52
# [1012 | 29.09] loss=1.34 avg=1.51
# [1013 | 30.67] loss=1.16 avg=1.48
# [1014 | 32.25] loss=0.99 avg=1.44
# [1015 | 33.83] loss=1.55 avg=1.45
# [1016 | 35.40] loss=1.84 avg=1.48
# [1017 | 36.98] loss=1.82 avg=1.50
# [1018 | 38.57] loss=2.06 avg=1.53
# [1019 | 40.16] loss=1.54 avg=1.53
# [1020 | 41.76] loss=1.22 avg=1.52
# [1021 | 43.35] loss=2.53 avg=1.57
# [1022 | 44.95] loss=1.84 avg=1.58
# [1023 | 46.55] loss=1.29 avg=1.57
# [1024 | 48.16] loss=1.19 avg=1.55
# [1025 | 49.77] loss=1.70 avg=1.56
# [1026 | 51.38] loss=1.50 avg=1.56
# [1027 | 52.99] loss=0.85 avg=1.53
# [1028 | 54.61] loss=1.21 avg=1.51
# [1029 | 56.24] loss=1.25 avg=1.50
# [1030 | 57.87] loss=1.47 avg=1.50
# [1031 | 59.49] loss=1.44 avg=1.50
# [1032 | 61.13] loss=0.94 avg=1.48
# [1033 | 62.77] loss=1.33 avg=1.47
# [1034 | 64.41] loss=1.77 avg=1.48
# [1035 | 66.06] loss=1.38 avg=1.48
# [1036 | 67.72] loss=1.08 avg=1.47
# [1037 | 69.39] loss=1.57 avg=1.47
# [1038 | 71.05] loss=1.15 avg=1.46
# [1039 | 72.71] loss=1.65 avg=1.47
# [1040 | 74.38] loss=1.98 avg=1.48
# [1041 | 76.05] loss=1.18 avg=1.47
# [1042 | 77.71] loss=1.23 avg=1.47
# [1043 | 79.38] loss=1.51 avg=1.47
# [1044 | 81.04] loss=1.18 avg=1.46
# [1045 | 82.70] loss=1.52 avg=1.46
# [1046 | 84.35] loss=1.29 avg=1.46
# [1047 | 85.99] loss=1.28 avg=1.45
# [1048 | 87.64] loss=1.87 avg=1.46
# [1049 | 89.27] loss=1.91 avg=1.47
# [1050 | 90.90] loss=1.25 avg=1.47
# [1051 | 92.54] loss=1.28 avg=1.46
# [1052 | 94.17] loss=1.65 avg=1.47
# [1053 | 95.80] loss=1.25 avg=1.46
# [1054 | 97.43] loss=1.35 avg=1.46
# [1055 | 99.06] loss=1.90 avg=1.47
# [1056 | 100.68] loss=1.34 avg=1.47
# [1057 | 102.32] loss=1.44 avg=1.47
# [1058 | 103.95] loss=1.68 avg=1.47
# [1059 | 105.56] loss=1.86 avg=1.48
# [1060 | 107.18] loss=1.01 avg=1.47
# [1061 | 108.80] loss=1.40 avg=1.47
# [1062 | 110.41] loss=1.34 avg=1.47
# [1063 | 112.03] loss=1.65 avg=1.47
# [1064 | 113.64] loss=1.57 avg=1.47
# [1065 | 115.26] loss=1.54 avg=1.47
# [1066 | 116.88] loss=1.46 avg=1.47
# [1067 | 118.49] loss=1.87 avg=1.48
# [1068 | 120.12] loss=1.10 avg=1.47
# [1069 | 121.73] loss=0.94 avg=1.46
# [1070 | 123.34] loss=1.03 avg=1.45
# [1071 | 124.95] loss=1.66 avg=1.46
# [1072 | 126.57] loss=1.72 avg=1.46
# [1073 | 128.18] loss=1.09 avg=1.46
# [1074 | 129.80] loss=0.90 avg=1.45
# [1075 | 131.43] loss=1.60 avg=1.45
# [1076 | 133.05] loss=1.47 avg=1.45
# [1077 | 134.67] loss=1.14 avg=1.44
# [1078 | 136.29] loss=0.66 avg=1.43
# [1079 | 137.91] loss=1.39 avg=1.43
# [1080 | 139.54] loss=1.73 avg=1.43
# [1081 | 141.15] loss=1.35 avg=1.43
# [1082 | 142.79] loss=1.20 avg=1.43
# [1083 | 144.41] loss=1.87 avg=1.44
# [1084 | 146.03] loss=1.04 avg=1.43
# [1085 | 147.65] loss=2.32 avg=1.44
# [1086 | 149.27] loss=1.38 avg=1.44
# [1087 | 150.90] loss=1.47 avg=1.44
# [1088 | 152.54] loss=1.47 avg=1.44
# [1089 | 154.16] loss=0.75 avg=1.43
# [1090 | 155.80] loss=1.46 avg=1.43
# [1091 | 157.43] loss=1.27 avg=1.43
# [1092 | 159.06] loss=1.18 avg=1.43
# [1093 | 160.68] loss=1.43 avg=1.43
# [1094 | 162.32] loss=1.27 avg=1.42
# [1095 | 163.95] loss=1.35 avg=1.42
# [1096 | 165.59] loss=1.23 avg=1.42
# [1097 | 167.24] loss=2.04 avg=1.43
# [1098 | 168.88] loss=1.10 avg=1.42
# [1099 | 170.51] loss=1.46 avg=1.42
# Generating samples...
# ======== SAMPLE 1 ========
# ’t going to say a word about it?’ Dean snarled.
#
# ‘Nooooo!’ shrieked Mrs Weasley. ‘I won’t forgive you if you don’t carry on like this before you go in for the sack!’
#
# ‘How did Mum and Dad know you weren’t going to the Cup with them?’ said Ron angrily. ‘Don’t you be daft to think they saw you going!’
#
# ‘I’ll explain later,’ said Hermione, and she left the kitchen.
#
# ‘You two are going to have to go down into the grounds and look for them!’ said Harry, who had been thinking the same thing, and he knew it; he and Ron had been pruning through the weeds outside their little hut all day.
#
# ‘We’re doing our best,’ said Ron, as they walked slowly back up the gravel path to the house. ‘Guess what? It worked. He can take that potion!’ He jumped as a long, dark figure leapt out from under the hedge, and Harry saw a red cloak emerge from it, and plunge into the ground. Harry’s heart leaped with joy; every fibre of him wanted to hug Ron, to console him, to tell him he’d been the brave hero in the end…
#
# He hit the brick wall where Ron had slipped and saw the shadow of a woman emerging from the cloak.
#
# ‘Hermione?’ said Ron, looking at her. ‘Can you tell us where –?’
#
# She walked away very fast, turning back to him.
#
# ‘You should have brought the golden egg with you,’ she said, when they had reached the foot of the hedge.
#
# ‘Yeah, but I didn’t think they had those kinds of things,’ said Harry.
#
# ‘Oh … you came back for your wedding ring, have you?’
#
# ‘What?’ said Harry, dumbstruck.
#
# ‘She left the bag at Hagrid’s without saying where she found it, and it went wandering off, thinking she had found it again. She chased after it for five minutes before spotting you and calling to you.’
#
# ‘What?’
#
# ‘She wanted to say hello to you, and wanted you to come to her for advice on how to get to the Cup, and it is a bit early to be making suggestions like that, anyway,’ said Hermione, looking very angry. ‘Don’t you worry about me!’
#
# Ron and Hermione looked really startled too.
#
# ‘Hermione, why are you shouting?’ said Harry quickly.
#
# ‘Because you were hoping Ron would go and see if I had forgotten to bring the egg,’ she said hastily. ‘Come back soon!’
#
# ‘Hermione, get out!’ Ron shouted. ‘I’m with you!’
#
# They hustled after her.
#
# ‘What is she going to do now?’ Harry said after a few minutes. ‘She can’t be so quick to judge someone because they’ve forgotten how to get to the Cup and end up lost!’
#
# ‘And that’s why you should never, ever judge a book by its cover,’ said Ron.
#
# ‘I hate to harp on you about it being best practice, but that hasn’t been tried,’ said Hermione. ‘The only person to have succeeded in getting to the Cup without the help of a Parvati-approved Egg were the Weasleys,’ and Harry’s hopes had always been that Parvati was the same as his godmother.
#
# ‘Why isn’t someone trying it?’ said Harry, still struggling to get past the rage burning so fiercely in his stomach. ‘Parvati? Hermione – why don’t you use a different dragon, could you? Dumbledore said there was still a lot of work to be done, he’s got reservations about the kind of power they might have to misuse.’
#
# ‘You mean the kind of power Dumbledore’s talking about?’
#
# ‘Of course I do,’ said Hermione, not speaking for the first time in weeks. ‘And that’s why I’m coming and getting you, to get you clear of this one.’
#
# ‘Hermione, I’m getting dressed!’ Harry called after her, as he left the little clearing. ‘
#
# [1100 | 197.57] loss=1.27 avg=1.42
# [1101 | 199.22] loss=2.02 avg=1.43
# [1102 | 200.86] loss=1.89 avg=1.44
# [1103 | 202.49] loss=1.32 avg=1.44
# [1104 | 204.13] loss=1.87 avg=1.44
# [1105 | 205.76] loss=1.16 avg=1.44
# [1106 | 207.40] loss=1.53 avg=1.44
# [1107 | 209.03] loss=1.48 avg=1.44
# [1108 | 210.67] loss=1.07 avg=1.44
# [1109 | 212.31] loss=1.36 avg=1.43
# [1110 | 213.94] loss=1.40 avg=1.43
# [1111 | 215.57] loss=1.40 avg=1.43
# [1112 | 217.21] loss=2.08 avg=1.44
# [1113 | 218.84] loss=1.76 avg=1.45
# [1114 | 220.47] loss=1.79 avg=1.45
# [1115 | 222.10] loss=1.40 avg=1.45
# [1116 | 223.74] loss=1.34 avg=1.45
# [1117 | 225.37] loss=1.59 avg=1.45
# [1118 | 227.00] loss=1.31 avg=1.45
# [1119 | 228.63] loss=1.38 avg=1.45
# [1120 | 230.26] loss=1.76 avg=1.45
# [1121 | 231.88] loss=1.14 avg=1.45
# [1122 | 233.51] loss=1.75 avg=1.45
# [1123 | 235.15] loss=2.33 avg=1.47
# [1124 | 236.77] loss=1.31 avg=1.46
# [1125 | 238.39] loss=1.08 avg=1.46
# [1126 | 240.03] loss=1.05 avg=1.45
# [1127 | 241.65] loss=1.11 avg=1.45
# [1128 | 243.28] loss=1.30 avg=1.45
# [1129 | 244.90] loss=1.47 avg=1.45
# [1130 | 246.53] loss=1.11 avg=1.44
# [1131 | 248.16] loss=1.00 avg=1.44
# [1132 | 249.79] loss=1.21 avg=1.43
# [1133 | 251.42] loss=1.05 avg=1.43
# [1134 | 253.05] loss=1.94 avg=1.43
# [1135 | 254.68] loss=1.20 avg=1.43
# [1136 | 256.31] loss=0.96 avg=1.42
# [1137 | 257.95] loss=1.45 avg=1.42
# [1138 | 259.58] loss=1.41 avg=1.42
# [1139 | 261.21] loss=1.28 avg=1.42
# [1140 | 262.83] loss=1.08 avg=1.42
# [1141 | 264.47] loss=1.89 avg=1.42
# [1142 | 266.10] loss=1.54 avg=1.43
# [1143 | 267.74] loss=1.36 avg=1.43
# [1144 | 269.37] loss=1.01 avg=1.42
# [1145 | 270.99] loss=1.11 avg=1.42
# [1146 | 272.62] loss=1.30 avg=1.41
# [1147 | 274.25] loss=1.38 avg=1.41
# [1148 | 275.87] loss=1.14 avg=1.41
# [1149 | 277.50] loss=1.23 avg=1.41
# [1150 | 279.14] loss=1.28 avg=1.41
# [1151 | 280.78] loss=1.62 avg=1.41
# [1152 | 282.41] loss=1.09 avg=1.40
# [1153 | 284.04] loss=1.11 avg=1.40
# [1154 | 285.67] loss=2.30 avg=1.41
# [1155 | 287.31] loss=1.77 avg=1.42
# [1156 | 288.95] loss=0.57 avg=1.41
# [1157 | 290.57] loss=1.37 avg=1.41
# [1158 | 292.20] loss=1.63 avg=1.41
# [1159 | 293.84] loss=1.07 avg=1.40
# [1160 | 295.47] loss=1.76 avg=1.41
# [1161 | 297.10] loss=0.94 avg=1.40
# [1162 | 298.73] loss=1.34 avg=1.40
# [1163 | 300.36] loss=1.34 avg=1.40
# [1164 | 301.99] loss=1.24 avg=1.40
# [1165 | 303.62] loss=1.06 avg=1.40
# [1166 | 305.26] loss=1.30 avg=1.39
# [1167 | 306.90] loss=1.50 avg=1.40
# [1168 | 308.53] loss=0.77 avg=1.39
# [1169 | 310.17] loss=0.82 avg=1.38
# [1170 | 311.81] loss=0.53 avg=1.37
# [1171 | 313.45] loss=0.92 avg=1.36
# [1172 | 315.08] loss=0.90 avg=1.36
# [1173 | 316.72] loss=1.72 avg=1.36
# [1174 | 318.34] loss=1.26 avg=1.36
# [1175 | 319.98] loss=1.98 avg=1.37
# [1176 | 321.61] loss=0.90 avg=1.36
# [1177 | 323.25] loss=0.52 avg=1.35
# [1178 | 324.88] loss=1.10 avg=1.35
# [1179 | 326.52] loss=0.65 avg=1.34
# [1180 | 328.16] loss=1.11 avg=1.34
# [1181 | 329.80] loss=1.06 avg=1.34
# [1182 | 331.44] loss=0.82 avg=1.33
# [1183 | 333.08] loss=1.20 avg=1.33
# [1184 | 334.72] loss=1.53 avg=1.33
# [1185 | 336.36] loss=1.12 avg=1.33
# [1186 | 338.00] loss=2.00 avg=1.34
# [1187 | 339.64] loss=1.25 avg=1.34
# [1188 | 341.27] loss=2.30 avg=1.35
# [1189 | 342.91] loss=1.01 avg=1.34
# [1190 | 344.55] loss=0.96 avg=1.34
# [1191 | 346.18] loss=0.75 avg=1.33
# [1192 | 347.83] loss=1.98 avg=1.34
# [1193 | 349.47] loss=1.52 avg=1.34
# [1194 | 351.11] loss=1.64 avg=1.34
# [1195 | 352.73] loss=1.73 avg=1.35
# [1196 | 354.37] loss=1.77 avg=1.35
# [1197 | 356.01] loss=1.33 avg=1.35
# [1198 | 357.64] loss=1.12 avg=1.35
# [1199 | 359.27] loss=1.70 avg=1.36
# Generating samples...
# ======== SAMPLE 1 ========
# ita he seemed to know how strong he is in his scar; one might even have regarded him as slightly larger than himself. Yet, he kept watching him closely, apparently trying to gauge how far the boy would go to recover his memories, or perhaps just to see if he would even listen.’
#
# When Harry had finished, and was looking down at the chess piece, he said, ‘Nice and slow.’
#
# And the boy, now looking suddenly very small, took the piece and swiftly moved it through several moves, trying to increase the distance between himself and the object of his longing.
#
# The thing that stood before Harry in the hole in the wall was a large, circular wooden pentagram, with a pentacle inside of it, and a crown of 15 stars near the top. It was as though the thing was looking down into his lap. It was a stone image of himself, moving, gazing at him through the pentagram, calculating, the boy’s fear seemed to come back. He felt a sudden surge of dizziness, and his spine felt as though it was ice-cold. The thing was watching him, calculating, assessing his strength and patience.
#
# After a further ten seconds, the thing was making room for the boy, and Harry stood up, looking around for Barty Crouch. He sat down, looking around for Barty Crouch, and realised as he sat down, that he hadn’t sat down at all. He stood up and pulled his robes off, looking around.
#
# The cave was empty; the hole had been left wide open for the boy to emerge into the daylight. Dazed and confused, he stood up, but saw that the thing he had stared at was no longer there; instead, it had vanished as though he was carrying a large black object in his arms. The thing that stood before him now was nothing more than grassy ground.
#
# Harry tried to follow it, but nothing could explain why it was following him; he could only see the grassy ground as he moved slowly along it, wondering. What was the thing after? What was it trying to get at?
#
# The thing drew nearer, but when Harry moved his Wand hand, the grass parted, and instead of becoming a foot deep, it seemed to be as wide as a football pitch, and he thought that might be the thing that had taken his father’s wand. But still the thing was following him; it was keeping silent and continuing to move in an east-wandering fashion.
#
# A pause, and then the thing stopped moving; it was merely standing there looking around in silence, as though it was waiting for something to happen. Finally, when Harry reached a dead stop, staring down into the cave, it raised its head, and pointed its wand at Harry.
#
# Harry let go of the piece of dirt, and looked around. There was nothing there. He had got the idea instantly; a hundred yards away, on the grassy ground, his father had been strangled. He let go of the stone pentagram, and took off running …
#
# He turned down a path that led further out into the misty grey, and, a short way beyond where he had stopped, there was a dark figure standing in a flowerbed, looking at him …
#
# It was Dumbledore. The look in the man’s eyes did not fade, nor did the slurring of his voice … he was pointing at Harry.
#
# At once, Harry felt as though a great, invisible weight were pulling him towards the dark silhouette. He had barely crossed the clearing when a loud pop echoed through the woods beyond. Harry staggered backwards. He looked behind him and saw a man in his mid-twenties, a broad brimmed hat, thick gloves, wands at his sides, and a gun lying on the ground, pointed right at him.
#
# Harry let out a scream – he was going to die. He clutched his wand tightly.
#
# Then he felt something other than pain sink deep into the core of his ribs, and rise to the navel. He looked up … he saw the dark silhouette of his father, standing next to a dead skrewt on a thicket of rose bushes – the thing from whose horn the curse had come …
#
# He felt the weight of the curse lift from his chest – he felt it pull him back towards the dark figure. It was his son! The thing that had hurt Sirius was right before his eyes … his father stood right before him, his wand outstretched, the dark outline of his father silhouetted against the rose bushes, and his black robes fluttering as he approached …
#
# The boy looked scared, still staring at his father. There was no fear in his silvery robes; his father was not the hairy wizard in black. Harry saw something moving behind Dumbledore, felt the familiar pull of something greater than himself …
#
# Harry felt himself
#
# [1200 | 383.44] loss=1.65 avg=1.36
# [1201 | 385.07] loss=1.37 avg=1.36
# [1202 | 386.70] loss=1.07 avg=1.36
# [1203 | 388.33] loss=1.95 avg=1.36
# [1204 | 389.95] loss=1.68 avg=1.37
# [1205 | 391.58] loss=1.27 avg=1.36
# [1206 | 393.22] loss=0.95 avg=1.36
# [1207 | 394.84] loss=1.06 avg=1.36
# [1208 | 396.46] loss=1.92 avg=1.36
# [1209 | 398.09] loss=1.34 avg=1.36
# [1210 | 399.72] loss=0.95 avg=1.36
# [1211 | 401.34] loss=1.51 avg=1.36
# [1212 | 402.97] loss=1.26 avg=1.36
# [1213 | 404.60] loss=0.92 avg=1.35
# [1214 | 406.23] loss=1.25 avg=1.35
# [1215 | 407.87] loss=1.25 avg=1.35
# [1216 | 409.49] loss=1.33 avg=1.35
# [1217 | 411.12] loss=0.89 avg=1.35
# [1218 | 412.76] loss=1.41 avg=1.35
# [1219 | 414.39] loss=1.12 avg=1.34
# [1220 | 416.02] loss=1.32 avg=1.34
# [1221 | 417.66] loss=0.98 avg=1.34
# [1222 | 419.28] loss=1.06 avg=1.34
# [1223 | 420.91] loss=0.45 avg=1.33
# [1224 | 422.53] loss=1.03 avg=1.32
# [1225 | 424.17] loss=1.26 avg=1.32
# [1226 | 425.80] loss=1.16 avg=1.32
# [1227 | 427.44] loss=1.33 avg=1.32
# [1228 | 429.06] loss=0.99 avg=1.32
# [1229 | 430.69] loss=2.39 avg=1.33
# [1230 | 432.32] loss=1.45 avg=1.33
# [1231 | 433.95] loss=1.96 avg=1.34
# [1232 | 435.59] loss=1.30 avg=1.34
# [1233 | 437.23] loss=1.48 avg=1.34
# [1234 | 438.86] loss=1.37 avg=1.34
# [1235 | 440.50] loss=1.43 avg=1.34
# [1236 | 442.14] loss=1.36 avg=1.34
# [1237 | 443.77] loss=0.81 avg=1.33
# [1238 | 445.41] loss=1.58 avg=1.34
# [1239 | 447.05] loss=1.61 avg=1.34
# [1240 | 448.69] loss=1.29 avg=1.34
# [1241 | 450.32] loss=1.11 avg=1.34
# [1242 | 451.96] loss=1.57 avg=1.34
# [1243 | 453.59] loss=1.43 avg=1.34
# [1244 | 455.23] loss=1.18 avg=1.34
# [1245 | 456.88] loss=1.29 avg=1.34
# [1246 | 458.52] loss=1.09 avg=1.34
# [1247 | 460.17] loss=0.83 avg=1.33
# [1248 | 461.80] loss=1.16 avg=1.33
# [1249 | 463.45] loss=0.75 avg=1.32
# [1250 | 465.09] loss=1.19 avg=1.32
# [1251 | 466.73] loss=1.22 avg=1.32
# [1252 | 468.36] loss=1.53 avg=1.32
# [1253 | 470.00] loss=1.50 avg=1.32
# [1254 | 471.64] loss=1.49 avg=1.33
# [1255 | 473.27] loss=0.73 avg=1.32
# [1256 | 474.91] loss=0.60 avg=1.31
# [1257 | 476.54] loss=1.12 avg=1.31
# [1258 | 478.18] loss=0.95 avg=1.31
# [1259 | 479.80] loss=0.66 avg=1.30
# [1260 | 481.44] loss=1.37 avg=1.30
# [1261 | 483.07] loss=1.83 avg=1.30
# [1262 | 484.69] loss=1.89 avg=1.31
# [1263 | 486.32] loss=1.65 avg=1.31
# [1264 | 487.96] loss=0.61 avg=1.31
# [1265 | 489.60] loss=2.05 avg=1.32
# [1266 | 491.24] loss=1.56 avg=1.32
# [1267 | 492.88] loss=1.69 avg=1.32
# [1268 | 494.52] loss=1.06 avg=1.32
# [1269 | 496.16] loss=1.37 avg=1.32
# [1270 | 497.79] loss=1.01 avg=1.32
# [1271 | 499.43] loss=0.78 avg=1.31
# [1272 | 501.07] loss=0.81 avg=1.31
# [1273 | 502.71] loss=0.96 avg=1.30
# [1274 | 504.34] loss=1.57 avg=1.30
# [1275 | 505.98] loss=1.70 avg=1.31
# [1276 | 507.62] loss=1.33 avg=1.31
# [1277 | 509.26] loss=1.39 avg=1.31
# [1278 | 510.89] loss=0.76 avg=1.30
# [1279 | 512.52] loss=1.83 avg=1.31
# [1280 | 514.16] loss=2.21 avg=1.32
# [1281 | 515.79] loss=1.57 avg=1.32
# [1282 | 517.42] loss=1.66 avg=1.33
# [1283 | 519.06] loss=1.13 avg=1.32
# [1284 | 520.70] loss=0.89 avg=1.32
# [1285 | 522.34] loss=2.54 avg=1.33
# [1286 | 523.96] loss=1.21 avg=1.33
# [1287 | 525.59] loss=1.50 avg=1.33
# [1288 | 527.23] loss=1.17 avg=1.33
# [1289 | 528.87] loss=1.73 avg=1.33
# [1290 | 530.51] loss=1.66 avg=1.34
# [1291 | 532.15] loss=0.88 avg=1.33
# [1292 | 533.77] loss=1.37 avg=1.33
# [1293 | 535.41] loss=1.44 avg=1.33
# [1294 | 537.04] loss=1.18 avg=1.33
# [1295 | 538.68] loss=1.27 avg=1.33
# [1296 | 540.31] loss=1.01 avg=1.33
# [1297 | 541.93] loss=0.98 avg=1.33
# [1298 | 543.57] loss=0.57 avg=1.32
# [1299 | 545.21] loss=1.46 avg=1.32
# Generating samples...
# ======== SAMPLE 1 ========
#  Ron Weasley. For one moment, Harry thought –
#
# But what if Dumbledore didn’t recognise him? That would be one thing; but, for one moment, he was seeing something very peculiar indeed…
#
# ‘There you are, Cornelius!’ Moody’s excited voice boomed, very happily squealing into his fist. ‘I’ve got it now! I’ve got it now! A hundred points, sir – a hundred points – just give me a sign – give me a sign, you’ll be docked one hundred points – you’ll be docked one hundred points – give me a sign – you’ll be docked one hundred points – you’ll be docked one hundred points – what’s that?’
#
# Harry thought he could hardly hear himself talking; he thought he might faint. This was madness!
#
# ‘Dumbledore’s got it, then, Harry! Dumbledore’s got it, I’ll give him that!’
#
# Moody didn’t sound as though he was terribly pleased about this turn of events. He was leaning very heavily in, grinning, and shouting, ‘Give me a sign – oh – tell me more, Harry – tell me more, all right, Mr Crouch –’
#
# ‘How many times do I have to tell you – more than I need, Moody?’ Harry asked sternly.
#
# ‘I know that, Harry,’ said Moody dismissively. ‘You’ll find out shortly.’
#
# Moody stood there, gaping into his desk, looking over the top of his Hat, which had not yet started to glow with golden sparks. When, in the next moment, his desk light flickered to life, Moody’s face came into view.
#
# His mouth was a very ugly shade of gold, and drooping fangs bared serrated fangs. It looked as though he was holding a new club.
#
# For one fleeting second, Harry seriously considered pulling the plug on the Cloak, and trying and see what was going on. Then he remembered that Cedric was still talking, and could have sworn Moody’s face had flashed across the portrait hole.
#
# ‘What d’you plan to do now, Hagrid?’ said Moody abruptly.
#
# ‘I have to go and see Dumbledore, Hagrid …’ said Harry slowly.
#
# ‘He knows that, Harry?’ said Hagrid. ‘He asks you to come and see him often … Dumbledore’s got a prod in his side he’d like to prove right, Potter, or he’d sack him, as the case may be.’
#
# ‘Come on, Hagrid,’ said Harry stubbornly, ‘tell Dumbledore I’ll take my Cloak straight back, and I’ll take it any minute now …’
#
# Hagrid gave him one last look before climbing into the horse-drawn cart, and setting off.
#
# ‘How did he know I could leave my trunk here?’ Harry said to Hagrid.
#
# ‘It’s not that simple, Potter,’ said Hagrid placidly. ‘Dumbledore doesn’t like being trifled with, but he has other ideas. Dumbledore told Hagrid to look for Dumbledore in the woods when he was passing through, and Hagrid followed him. Hagrid has been passing Dumbledore rumours about you all this time … you never really took Harry’s name when you were apart of the Triwizard Tournament. I was rather surprised when Dumbledore told Hagrid to send you an owl before we got to the World Cup. Only a very few of your old friends still call themselves friends with you, and I think they might be tempted to take sides against you if they heard what Dumbledore has in store for you this time –’
#
# ‘You’ve got to be joking,’ said Harry. ‘You’ve got to be kidding … why would Dumbledore tell Hagrid to send you an owl before the World Cup starts? He’d have sent me straight through at the end of quarter-prize.’
#
# But Hagrid didn’t laugh; he didn’t sneer, shrug, or mutter something sneeringly like that. He just stared at Harry, and after a moment’s stunned silence said quietly, ‘There is no World Cup, Harry. Dumbledore says you will go to the Cup.’
#
# ‘What?’
#
# ‘No, Harry, there is no World Cup,’ said Hagrid firmly, staring at Harry through his Half-moon spectacles again
#
# [1300 | 569.58] loss=1.25 avg=1.32
# [1301 | 571.21] loss=1.12 avg=1.32
# [1302 | 572.84] loss=1.40 avg=1.32
# [1303 | 574.47] loss=1.14 avg=1.32
# [1304 | 576.10] loss=0.82 avg=1.31
# [1305 | 577.72] loss=1.26 avg=1.31
# [1306 | 579.35] loss=1.35 avg=1.31
# [1307 | 580.98] loss=0.71 avg=1.30
# [1308 | 582.61] loss=1.00 avg=1.30
# [1309 | 584.23] loss=2.26 avg=1.31
# [1310 | 585.86] loss=0.95 avg=1.31
# [1311 | 587.49] loss=2.08 avg=1.31
# [1312 | 589.12] loss=1.47 avg=1.32
# [1313 | 590.74] loss=0.59 avg=1.31
# [1314 | 592.36] loss=1.10 avg=1.31
# [1315 | 593.99] loss=1.57 avg=1.31
# [1316 | 595.62] loss=2.19 avg=1.32
# [1317 | 597.25] loss=2.34 avg=1.33
# [1318 | 598.88] loss=1.07 avg=1.33
# [1319 | 600.50] loss=1.31 avg=1.33
# [1320 | 602.13] loss=1.75 avg=1.33
# [1321 | 603.76] loss=0.82 avg=1.33
# [1322 | 605.39] loss=1.29 avg=1.33
# [1323 | 607.02] loss=1.72 avg=1.33
# [1324 | 608.66] loss=0.80 avg=1.32
# [1325 | 610.29] loss=1.56 avg=1.33
# [1326 | 611.93] loss=0.97 avg=1.32
# [1327 | 613.55] loss=1.11 avg=1.32
# [1328 | 615.18] loss=1.20 avg=1.32
# [1329 | 616.82] loss=1.31 avg=1.32
# [1330 | 618.45] loss=0.63 avg=1.31
# [1331 | 620.09] loss=1.70 avg=1.32
# [1332 | 621.72] loss=1.52 avg=1.32
# [1333 | 623.34] loss=1.17 avg=1.32
# [1334 | 624.98] loss=0.87 avg=1.31
# [1335 | 626.62] loss=0.76 avg=1.31
# [1336 | 628.26] loss=0.90 avg=1.30
# [1337 | 629.89] loss=1.08 avg=1.30
# [1338 | 631.54] loss=0.73 avg=1.29
# [1339 | 633.18] loss=0.93 avg=1.29
# [1340 | 634.81] loss=1.34 avg=1.29
# [1341 | 636.45] loss=1.78 avg=1.30
# [1342 | 638.08] loss=0.84 avg=1.29
# [1343 | 639.71] loss=1.06 avg=1.29
# [1344 | 641.34] loss=0.87 avg=1.28
# [1345 | 642.96] loss=1.24 avg=1.28
# [1346 | 644.60] loss=1.50 avg=1.29
# [1347 | 646.24] loss=1.22 avg=1.29
# [1348 | 647.86] loss=1.37 avg=1.29
# [1349 | 649.50] loss=0.88 avg=1.28
# [1350 | 651.14] loss=0.85 avg=1.28
# [1351 | 652.78] loss=0.81 avg=1.27
# [1352 | 654.41] loss=0.86 avg=1.27
# [1353 | 656.05] loss=1.58 avg=1.27
# [1354 | 657.69] loss=1.19 avg=1.27
# [1355 | 659.33] loss=0.93 avg=1.27
# [1356 | 660.96] loss=1.74 avg=1.27
# [1357 | 662.59] loss=0.51 avg=1.26
# [1358 | 664.23] loss=1.57 avg=1.27
# [1359 | 665.86] loss=1.29 avg=1.27
# [1360 | 667.49] loss=1.15 avg=1.27
# [1361 | 669.13] loss=0.89 avg=1.26
# [1362 | 670.76] loss=1.10 avg=1.26
# [1363 | 672.40] loss=0.61 avg=1.25
# [1364 | 674.03] loss=1.12 avg=1.25
# [1365 | 675.67] loss=0.80 avg=1.25
# [1366 | 677.31] loss=1.05 avg=1.25
# [1367 | 678.93] loss=1.64 avg=1.25
# [1368 | 680.56] loss=0.47 avg=1.24
# [1369 | 682.20] loss=1.57 avg=1.25
# [1370 | 683.83] loss=1.06 avg=1.24
# [1371 | 685.46] loss=0.73 avg=1.24
# [1372 | 687.10] loss=0.97 avg=1.24
# [1373 | 688.73] loss=0.98 avg=1.23
# [1374 | 690.37] loss=0.98 avg=1.23
# [1375 | 692.00] loss=1.12 avg=1.23
# [1376 | 693.63] loss=0.35 avg=1.22
# [1377 | 695.26] loss=1.48 avg=1.22
# [1378 | 696.88] loss=1.04 avg=1.22
# [1379 | 698.51] loss=1.94 avg=1.23
# [1380 | 700.14] loss=1.31 avg=1.23
# [1381 | 701.77] loss=0.97 avg=1.23
# [1382 | 703.41] loss=1.83 avg=1.23
# [1383 | 705.04] loss=0.97 avg=1.23
# [1384 | 706.67] loss=1.61 avg=1.23
# [1385 | 708.30] loss=1.02 avg=1.23
# [1386 | 709.93] loss=1.04 avg=1.23
# [1387 | 711.56] loss=0.74 avg=1.22
# [1388 | 713.19] loss=0.96 avg=1.22
# [1389 | 714.82] loss=1.35 avg=1.22
# [1390 | 716.45] loss=1.08 avg=1.22
# [1391 | 718.08] loss=1.35 avg=1.22
# [1392 | 719.71] loss=1.19 avg=1.22
# [1393 | 721.35] loss=1.55 avg=1.23
# [1394 | 722.97] loss=1.96 avg=1.23
# [1395 | 724.60] loss=1.28 avg=1.23
# [1396 | 726.22] loss=1.61 avg=1.24
# [1397 | 727.85] loss=0.96 avg=1.24
# [1398 | 729.48] loss=1.37 avg=1.24
# [1399 | 731.10] loss=1.18 avg=1.24
# Generating samples...
# ======== SAMPLE 1 ========
#  old, the boy with no ears had turned out to be a human. A very human, indeed; he even had the typical human tendency for wildness, in spite of his being an elf. He was dressed in the frayed raiment of a vagabond, his fly buzzing on the end of his dagger-skull.
#
# ‘You’re … you’re still alive, you know,’ he said at last. ‘You could be –?’
#
# ‘I can’t be alive,’ said Ron. ‘I know that.’
#
# ‘Well, I can be –?’ said Harry, incredulously. ‘No … I don’t know where you are, but it’s not likely that you would hear from me here unless you had urgent news.’
#
# At this, the Horntail grunted.
#
# ‘Harry, you know your past,’ Ron said, very angrily. ‘And this is no intrusion –’
#
# He seized Harry’s arm again, but there was no response.
#
# ‘You heard him, you heard right,’ Harry said. ‘Where are you from?’
#
# ‘Dublin,’ said the dragon, smiling. ‘They’re calling me Nagini.’
#
# ‘And?’ Harry asked.
#
# Ron’s arm was now around Harry’s throat, pulling him closer. ‘And what motive could you possibly have for calling someone a –?’
#
# ‘The name’s good,’ said Harry slowly.
#
# ‘’E’say you want to be known by it,’ said Ron.
#
# ‘No – no,’ said Harry. ‘It’s – it’s not fair.’
#
# ‘Harry,’ said Ron, very angrily, ‘It doesn’t matter what you’ve done. No one will ever know. You aren’t a hero, and you aren’t brave –’
#
# ‘What’re we going to do now?’ Hermione asked. ‘We’ll just pack up our stuff now?’
#
# ‘Oh – right –’ Harry said. He didn’t like the look of this particular danger, and he couldn’t think of any way out. Hermione was watching him intently now, trying to think whether he should speak again or not.
#
# ‘Ron!’ said Hermione, in a very loud voice. ‘Where’s Dumbledore?’
#
# ‘Dunno,’ said Ron, in confusion.
#
# ‘Well, we’ll go up to him,’ said Hermione. ‘I’ll come with him and him alone.’
#
# ‘No, no, we’ll go with Ron!’ said Ron happily, and they clambered out of the Great Hall, making sure of each other.
#
# ‘Good-bye, Harry,’ said Hermione.
#
# He waved to Harry as he passed.
#
# ‘Goodbye, too,’ said Harry back. He walked over to the castle once more, opened the heavy trunk beneath the stairs, pulled out his wand and quill, and set off for Hogwarts.
#
#
#
#
#
# — CHAPTER TWENTY-SEVEN —
#
#
# The Beginning
#
# Harry walked up the drive to his school through a sea of first-years, all of them staring with excitement at the Hogwarts map in the rearview mirror as he crossed the lawn. For a few seconds, Harry didn’t see who was grinning, and for a brief second he forgot about the map, because he heard:
#
# ‘Who’re you friends with?’
#
# Someone was laughing behind the castle wall. Harry sped up – he had a choice whether to turn around now – and there was Madam Rosmerta Rosmerling in the drive way with their dog, Houndshead ­– only, it looked like, four dogs; not that he really cared, really. As long as the ­– sorted themselves, he’d spent ten minutes pecking ­– and now they snacked happily next to him.
#
# ‘Er – erm …’ he said. ‘Er – what happened?’
#
# ‘Oh, great, great news, Harry!’ said Madam Rosmerlege happily.
#
# ‘Er – right – right …’
#
# ‘That you and Ron are going to be ­– together!’ she said. ‘How wonderful …
#
# [1400 | 755.23] loss=1.35 avg=1.24
# [1401 | 756.88] loss=1.63 avg=1.24
# [1402 | 758.51] loss=2.32 avg=1.25
# [1403 | 760.14] loss=1.49 avg=1.25
# [1404 | 761.77] loss=0.78 avg=1.25
# [1405 | 763.40] loss=0.86 avg=1.25
# [1406 | 765.03] loss=1.54 avg=1.25
# [1407 | 766.67] loss=0.95 avg=1.25
# [1408 | 768.30] loss=0.81 avg=1.24
# [1409 | 769.93] loss=1.03 avg=1.24
# [1410 | 771.55] loss=1.83 avg=1.25
# [1411 | 773.18] loss=0.92 avg=1.24
# [1412 | 774.81] loss=1.07 avg=1.24
# [1413 | 776.45] loss=1.02 avg=1.24
# [1414 | 778.08] loss=1.06 avg=1.24
# [1415 | 779.71] loss=1.22 avg=1.24
# [1416 | 781.34] loss=1.31 avg=1.24
# [1417 | 782.98] loss=0.83 avg=1.23
# [1418 | 784.61] loss=1.46 avg=1.23
# [1419 | 786.24] loss=1.35 avg=1.24
# [1420 | 787.86] loss=1.53 avg=1.24
# [1421 | 789.50] loss=1.05 avg=1.24
# [1422 | 791.13] loss=1.99 avg=1.24
# [1423 | 792.77] loss=1.06 avg=1.24
# [1424 | 794.40] loss=1.42 avg=1.24
# [1425 | 796.03] loss=0.62 avg=1.24
# [1426 | 797.66] loss=1.92 avg=1.25
# [1427 | 799.30] loss=1.63 avg=1.25
# [1428 | 800.92] loss=1.14 avg=1.25
# [1429 | 802.55] loss=1.25 avg=1.25
# [1430 | 804.17] loss=0.78 avg=1.24
# [1431 | 805.80] loss=0.67 avg=1.24
# [1432 | 807.43] loss=1.67 avg=1.24
# [1433 | 809.06] loss=0.78 avg=1.24
# [1434 | 810.69] loss=1.09 avg=1.24
# [1435 | 812.33] loss=0.92 avg=1.23
# [1436 | 813.96] loss=1.35 avg=1.23
# [1437 | 815.60] loss=1.40 avg=1.24
# [1438 | 817.23] loss=1.37 avg=1.24
# [1439 | 818.87] loss=0.87 avg=1.23
# [1440 | 820.50] loss=1.15 avg=1.23
# [1441 | 822.12] loss=0.96 avg=1.23
# [1442 | 823.74] loss=1.16 avg=1.23
# [1443 | 825.36] loss=1.07 avg=1.23
# [1444 | 826.99] loss=1.15 avg=1.23
# [1445 | 828.62] loss=1.65 avg=1.23
# [1446 | 830.26] loss=1.56 avg=1.23
# [1447 | 831.89] loss=1.26 avg=1.23
# [1448 | 833.52] loss=1.55 avg=1.24
# [1449 | 835.14] loss=1.12 avg=1.24
# [1450 | 836.78] loss=1.71 avg=1.24
# [1451 | 838.41] loss=1.20 avg=1.24
# [1452 | 840.03] loss=1.15 avg=1.24
# [1453 | 841.66] loss=0.96 avg=1.24
# [1454 | 843.30] loss=0.88 avg=1.23
# [1455 | 844.94] loss=1.46 avg=1.24
# [1456 | 846.57] loss=1.38 avg=1.24
# [1457 | 848.20] loss=0.83 avg=1.23
# [1458 | 849.84] loss=1.38 avg=1.23
# [1459 | 851.48] loss=1.18 avg=1.23
# [1460 | 853.11] loss=1.73 avg=1.24
# [1461 | 854.75] loss=1.93 avg=1.25
# [1462 | 856.39] loss=1.04 avg=1.24
# [1463 | 858.03] loss=0.51 avg=1.24
# [1464 | 859.65] loss=1.31 avg=1.24
# [1465 | 861.28] loss=0.75 avg=1.23
# [1466 | 862.92] loss=1.36 avg=1.23
# [1467 | 864.55] loss=1.05 avg=1.23
# [1468 | 866.18] loss=0.67 avg=1.23
# [1469 | 867.82] loss=1.07 avg=1.22
# [1470 | 869.45] loss=1.43 avg=1.23
# [1471 | 871.08] loss=0.84 avg=1.22
# [1472 | 872.72] loss=1.24 avg=1.22
# [1473 | 874.36] loss=1.09 avg=1.22
# [1474 | 876.00] loss=1.03 avg=1.22
# [1475 | 877.64] loss=0.72 avg=1.21
# [1476 | 879.28] loss=1.02 avg=1.21
# [1477 | 880.91] loss=0.49 avg=1.21
# [1478 | 882.55] loss=1.61 avg=1.21
# [1479 | 884.17] loss=0.83 avg=1.21
# [1480 | 885.81] loss=2.74 avg=1.22
# [1481 | 887.44] loss=1.25 avg=1.22
# [1482 | 889.08] loss=0.96 avg=1.22
# [1483 | 890.71] loss=0.95 avg=1.22
# [1484 | 892.35] loss=1.31 avg=1.22
# [1485 | 893.99] loss=0.49 avg=1.21
# [1486 | 895.63] loss=1.36 avg=1.21
# [1487 | 897.26] loss=0.76 avg=1.21
# [1488 | 898.90] loss=0.45 avg=1.20
# [1489 | 900.54] loss=0.91 avg=1.20
# [1490 | 902.18] loss=1.29 avg=1.20
# [1491 | 903.82] loss=1.24 avg=1.20
# [1492 | 905.46] loss=0.50 avg=1.19
# [1493 | 907.09] loss=0.68 avg=1.19
# [1494 | 908.73] loss=0.93 avg=1.18
# [1495 | 910.37] loss=1.23 avg=1.18
# [1496 | 912.00] loss=0.94 avg=1.18
# [1497 | 913.64] loss=0.71 avg=1.18
# [1498 | 915.29] loss=0.89 avg=1.17
# [1499 | 916.93] loss=1.10 avg=1.17
# Generating samples...
# ======== SAMPLE 1 ========
# ’ said Ron quietly.
#
# ‘There’s nothing I like more than being in seventh year,’ Hermione said thoughtfully.‘But even then … even then I’d have liked going in on the night Shrek came sniffing around. He got quite close to me, I can tell you. He was laughing …’
#
# But nothing had really gone wrong this evening, apparently. Harry took a deep, steadying breath, and continued, ‘Shrek is an over-achiever – he’s never had a girlfriend, which means he really only likes pretty women. He was going to bring in a new member for tonight, though.’
#
# Hermione’s bright eyes filled with tears again, ‘– who else?’
#
# ‘I’d say Moody,’ said Harry.
#
# ‘How … like him?’
#
# ‘I think so,’ said Harry, and he took a deep, steadying breath, and started on his suggestion to listen to the last few syllables of Moody’s voice as he said it.
#
# It sounded as though Moody, quite apart from the heavy, distant thud of Moody’s heavy boots upon the stone floor, as though he was talking in a whisper – or rather he seemed to be, the dull thud of a clunking, metallic clock –
#
# ‘Moody? Moody? Dark wizard?’
#
# There was a strange, inhuman snap to Moody’s throat, as though he had suddenly found he could not keep the words out. His slits in his robes seemed to close again, and he spoke in a whisper now …
#
# ‘Dumbledore is behind bars, I can tell you that. He tried to recruit you, to see whether you would do the task. He was unsuccessful.’
#
# ‘Alastor – I trust that Albus Dumbledore is not accompanying Moody into battle?’
#
# ‘No,’ said Moody sadly, gazing down at the prisoner across his robes, who was Harry. ‘Not today …’
#
# Ron sat cross-legged in the corner, his head on Harry’s shoulder.
#
# ‘So …’ said Moody quietly, ‘unless …’
#
# ‘Moody?’ Ron muttered.
#
# ‘What d’you mean, Professor?’ said Harry slowly.
#
# Moody’s eyes flickered over Harry’s face. He looked at Harry with unusual intensity for a moment, and then said, ‘Moody … he became Chief Warlock when I took over as your champion. Long ago … back when you were still in Hogwarts … there came a time when the Department of International Magical Co-operation –’
#
# ‘What?’ said Harry.
#
# ‘The Ministry of Magic … the Ministry of Magic … came calling,’ said Moody. ‘I was asked to join up for a short tour of duty … a little fishing …’
#
# ‘What were you doing?’ said Harry.
#
# ‘Sick and tired of dealing with Diggory and Karkaroff,’ said Moody, his eyes upon Harry again. ‘In the end, they asked for a replacement, and I was asked to join – so I went along with it, and joined the Dementors themselves.’
#
# Moody’s eyes flickered over Harry’s face, too; then he said, ‘I was under orders to use the Fidelius Charm for a month, to keep a close eye on Diggory and Karkaroff … and I think I can trust them now – they told me in person what was in store for them … and then they brought in the Restricted Section …’
#
# ‘What are they doing, the Restricted Section?’ said Harry slowly.
#
# Moody’s eyes flickered back to Harry.
#
# ‘A Ministry wizard has been keeping watch on the inside,’ he said softly. ‘Not all that long ago, we took care of most of the Ministry wizards, back when they were the greatest wizards on the face of the earth … and now they’re monitoring everything that’s on the inside, and letting certain people through who would rather burn in Hell than return to us.’
#
# Moody’s eyes flickered suddenly up at Harry.
#
# ‘You are very brave,’ he said. His magic was now powerful and dangerous, and strange things were happening to Harry. His eyes were watering in their sockets; he couldn’t bear to think any more …
#
# ‘He’
#
# [1500 | 941.06] loss=2.50 avg=1.19
# [1501 | 942.69] loss=0.91 avg=1.18
# [1502 | 944.33] loss=0.94 avg=1.18
# [1503 | 945.96] loss=2.42 avg=1.19
# [1504 | 947.59] loss=0.52 avg=1.19
# [1505 | 949.23] loss=1.05 avg=1.19
# [1506 | 950.85] loss=0.52 avg=1.18
# [1507 | 952.47] loss=1.34 avg=1.18
# [1508 | 954.10] loss=0.97 avg=1.18
# [1509 | 955.73] loss=1.25 avg=1.18
# [1510 | 957.36] loss=0.75 avg=1.17
# [1511 | 958.99] loss=1.07 avg=1.17
# [1512 | 960.63] loss=0.84 avg=1.17
# [1513 | 962.26] loss=1.02 avg=1.17
# [1514 | 963.89] loss=0.71 avg=1.16
# [1515 | 965.53] loss=1.45 avg=1.17
# [1516 | 967.15] loss=1.07 avg=1.17
# [1517 | 968.79] loss=1.22 avg=1.17
# [1518 | 970.42] loss=2.41 avg=1.18
# [1519 | 972.04] loss=0.95 avg=1.18
# [1520 | 973.66] loss=1.77 avg=1.18
# [1521 | 975.30] loss=0.77 avg=1.18
# [1522 | 976.94] loss=1.08 avg=1.18
# [1523 | 978.57] loss=0.94 avg=1.18
# [1524 | 980.21] loss=1.58 avg=1.18
# [1525 | 981.85] loss=0.43 avg=1.17
# [1526 | 983.48] loss=1.20 avg=1.17
# [1527 | 985.12] loss=0.40 avg=1.16
# [1528 | 986.74] loss=0.66 avg=1.16
# [1529 | 988.38] loss=0.76 avg=1.16
# [1530 | 990.00] loss=1.60 avg=1.16
# [1531 | 991.63] loss=1.43 avg=1.16
# [1532 | 993.27] loss=0.94 avg=1.16
# [1533 | 994.91] loss=0.96 avg=1.16
# [1534 | 996.54] loss=0.78 avg=1.15
# [1535 | 998.18] loss=1.61 avg=1.16
# [1536 | 999.82] loss=1.03 avg=1.16
# [1537 | 1001.46] loss=1.14 avg=1.16
# [1538 | 1003.09] loss=1.33 avg=1.16
# [1539 | 1004.72] loss=0.64 avg=1.15
# [1540 | 1006.35] loss=1.05 avg=1.15
# [1541 | 1007.98] loss=1.00 avg=1.15
# [1542 | 1009.62] loss=0.95 avg=1.15
# [1543 | 1011.26] loss=0.86 avg=1.15
# [1544 | 1012.90] loss=0.96 avg=1.14
# [1545 | 1014.54] loss=0.85 avg=1.14
# [1546 | 1016.18] loss=1.11 avg=1.14
# [1547 | 1017.82] loss=0.83 avg=1.14
# [1548 | 1019.46] loss=1.10 avg=1.14
# [1549 | 1021.10] loss=0.79 avg=1.13
# [1550 | 1022.74] loss=0.63 avg=1.13
# [1551 | 1024.38] loss=0.97 avg=1.13
# [1552 | 1026.02] loss=0.73 avg=1.12
# [1553 | 1027.66] loss=1.82 avg=1.13
# [1554 | 1029.30] loss=0.81 avg=1.13
# [1555 | 1030.94] loss=1.68 avg=1.13
# [1556 | 1032.57] loss=0.97 avg=1.13
# [1557 | 1034.21] loss=1.47 avg=1.13
# [1558 | 1035.85] loss=0.69 avg=1.13
# [1559 | 1037.50] loss=1.42 avg=1.13
# [1560 | 1039.13] loss=2.31 avg=1.14
# [1561 | 1040.78] loss=1.18 avg=1.15
# [1562 | 1042.42] loss=1.12 avg=1.15
# [1563 | 1044.06] loss=1.40 avg=1.15
# [1564 | 1045.70] loss=1.44 avg=1.15
# [1565 | 1047.34] loss=1.03 avg=1.15
# [1566 | 1048.97] loss=1.89 avg=1.16
# [1567 | 1050.62] loss=0.85 avg=1.15
# [1568 | 1052.25] loss=1.16 avg=1.15
# [1569 | 1053.88] loss=0.58 avg=1.15
# [1570 | 1055.53] loss=1.03 avg=1.15
# [1571 | 1057.17] loss=0.87 avg=1.14
# [1572 | 1058.80] loss=0.62 avg=1.14
# [1573 | 1060.43] loss=1.82 avg=1.15
# [1574 | 1062.07] loss=1.88 avg=1.15
# [1575 | 1063.70] loss=0.35 avg=1.14
# [1576 | 1065.33] loss=0.81 avg=1.14
# [1577 | 1066.96] loss=1.26 avg=1.14
# [1578 | 1068.59] loss=0.91 avg=1.14
# [1579 | 1070.23] loss=1.55 avg=1.14
# [1580 | 1071.86] loss=1.10 avg=1.14
# [1581 | 1073.50] loss=0.68 avg=1.14
# [1582 | 1075.14] loss=0.78 avg=1.14
# [1583 | 1076.77] loss=1.00 avg=1.13
# [1584 | 1078.40] loss=0.43 avg=1.13
# [1585 | 1080.02] loss=0.69 avg=1.12
# [1586 | 1081.66] loss=0.92 avg=1.12
# [1587 | 1083.28] loss=0.78 avg=1.12
# [1588 | 1084.92] loss=1.14 avg=1.12
# [1589 | 1086.54] loss=1.51 avg=1.12
# [1590 | 1088.18] loss=0.53 avg=1.12
# [1591 | 1089.81] loss=1.17 avg=1.12
# [1592 | 1091.45] loss=1.45 avg=1.12
# [1593 | 1093.07] loss=1.72 avg=1.13
# [1594 | 1094.70] loss=0.87 avg=1.12
# [1595 | 1096.34] loss=0.94 avg=1.12
# [1596 | 1097.97] loss=1.28 avg=1.12
# [1597 | 1099.60] loss=2.19 avg=1.13
# [1598 | 1101.22] loss=0.37 avg=1.13
# [1599 | 1102.85] loss=1.50 avg=1.13
# Generating samples...
# ======== SAMPLE 1 ========
# ��
#
# ‘Er, Mr Bagman’s done it!’ said Hermione loudly. ‘“He’s managed to turn Harry Potter into a dragon!” Hagrid’s done it, Professor Moody, you’ve got to be joking!” He raised his wand into the air, and started dancing.
#
# ‘What?’ said Ron, in alarm.
#
# ‘That was incredible, Professor,’ said Hermione, ‘that wasn’t … that was amazing!’
#
# ‘You can keep talking to me like a normal person,’ said Harry in frustration, ‘I just want to know if Hagrid really is putting out the word, or if he’s just trying to make himself popular.’
#
# ‘Well … if he’s doing it because he wants to be famous,’ said Hermione reluctantly, ‘that means he needs to get through the Quidditch World Cup early.’
#
# It turned out that, on the day of the Quidditch World Cup, Professor Dumbledore had invited the entire Chamber of Secrets to join him at Hogwarts. This included Hagrid, who had been keeping an eye on the door because of his connection to the ministry. However, when the Weasleys arrived with lunch on the table, Hagrid said he was waiting in the corridor. He did not look too keen about returning to his old ways, though; he was obviously very relieved to be back doing ordinary chores, and would not accept an iced gingerbread house-elf biscuit.
#
# As usual, Mrs Weasley did the house-elves’ labour, feeding them freshly boiled dinners, cakes and sandwiches. Hagrid was surprisingly pleasant about it all – he had not been when Harry, Ron and Hermione, had needed food. Mrs Weasley, however, appeared to enjoy torturing the Weasleys, and was particularly tickled when a particularly vicious torture-fish called 'Shadrach’ caught her wrist.
#
# ‘Harry, you can’t touch me like that!’ she said angrily. ‘Stop it!’
#
# ‘You – you really think I don’t have the elasticity of a jellyfish, missy?’
#
# ‘Don’t lie to me!’ she hissed. She had twisted a nail into a very small knot, and was twisting it back and forth over her forearm, exerting herself to painful effect. Harry felt a twinge of sympathy for her, though he doubted if she would have dared say this if Mrs Weasley had not been tormenting him. Hermione was frowning, glowering, over her shoulder as she hurried to patching a large hole in a hard surface with her napkin, evidently under the impression that Harry had touched her.
#
# The crusty old beetle-paper lantern seemed to work as it had always done, although the flames were now much brighter and the smell of burning toast and barbecue wafted higher into the air. As dusk crept nearer, and the grey sky filled with stars, pockets of haze came over Harry’s vision. He was remembering something.
#
# The Worm Cult was on the march again … it was only a matter of time before they reached the Weasleys’ house. Harry was sitting in his fourth floor room, having finished packing for the day, when Voldemort’s followers burst through the door behind him. One of them brandished a large club, and the Weasleys’ windows were shattered by the impact. A second wizard hit Harry on the back of his neck; his glasses fell off and shattered; and he was barely holding on as Ron put him under an enormous amount of pressure.
#
# ‘Who’re you trying to attack?’ Ron bellowed at Harry, brandishing his wand.
#
# ‘Viktor!’ Harry yelled, using Ron’s catch-all spell-name, and scattering the Wronski Feint around him.
#
# ‘Familiar! Dragon Stinger!’ Ron bellowed, and a blast like a bomb hit Harry squarely in the face. It hit his left cheek, on the bridge of his nose, but fortunately he had a piece of the shattered glass on me.’
#
# ‘Stay back, that bomb’s dangerous!’ yelled Moody.
#
# Moody threw himself between Ron and Harry, who were trembling with fear, as the gigantic black dragon in the picture on the door swelled into a full-fledged man – and his head swelled. Harry saw the horrible, reptilian face of the dragon protruding from behind thick, black, spiked armoury-card sleeves. He knew he wasn’t alone; he had barely noticed the great black eyes staring back at him as the door closed
#
# [1600 | 1127.07] loss=1.09 avg=1.13
# [1601 | 1128.70] loss=0.96 avg=1.13
# [1602 | 1130.33] loss=0.75 avg=1.12
# [1603 | 1131.97] loss=0.84 avg=1.12
# [1604 | 1133.59] loss=1.40 avg=1.12
# [1605 | 1135.23] loss=0.43 avg=1.12
# [1606 | 1136.86] loss=1.05 avg=1.12
# [1607 | 1138.50] loss=0.79 avg=1.11
# [1608 | 1140.13] loss=1.08 avg=1.11
# [1609 | 1141.77] loss=0.84 avg=1.11
# [1610 | 1143.40] loss=1.81 avg=1.12
# [1611 | 1145.03] loss=0.68 avg=1.11
# [1612 | 1146.66] loss=1.01 avg=1.11
# [1613 | 1148.29] loss=0.77 avg=1.11
# [1614 | 1149.91] loss=0.90 avg=1.11
# [1615 | 1151.54] loss=0.38 avg=1.10
# [1616 | 1153.18] loss=1.47 avg=1.10
# [1617 | 1154.81] loss=1.12 avg=1.10
# [1618 | 1156.44] loss=0.80 avg=1.10
# [1619 | 1158.07] loss=1.29 avg=1.10
# [1620 | 1159.71] loss=1.13 avg=1.10
# [1621 | 1161.34] loss=0.97 avg=1.10
# [1622 | 1162.97] loss=1.23 avg=1.10
# [1623 | 1164.61] loss=0.75 avg=1.10
# [1624 | 1166.23] loss=0.57 avg=1.09
# [1625 | 1167.87] loss=1.67 avg=1.10
# [1626 | 1169.49] loss=1.52 avg=1.10
# [1627 | 1171.13] loss=1.19 avg=1.10
# [1628 | 1172.75] loss=0.78 avg=1.10
# [1629 | 1174.38] loss=1.56 avg=1.10
# [1630 | 1176.02] loss=1.59 avg=1.11
# [1631 | 1177.66] loss=0.62 avg=1.10
# [1632 | 1179.29] loss=1.15 avg=1.11
# [1633 | 1180.93] loss=1.76 avg=1.11
# [1634 | 1182.56] loss=1.03 avg=1.11
# [1635 | 1184.20] loss=1.35 avg=1.11
# [1636 | 1185.84] loss=1.26 avg=1.11
# [1637 | 1187.47] loss=1.81 avg=1.12
# [1638 | 1189.09] loss=0.61 avg=1.12
# [1639 | 1190.72] loss=0.70 avg=1.11
# [1640 | 1192.35] loss=0.52 avg=1.11
# [1641 | 1193.98] loss=0.85 avg=1.10
# [1642 | 1195.62] loss=1.19 avg=1.10
# [1643 | 1197.25] loss=0.76 avg=1.10
# [1644 | 1198.89] loss=1.29 avg=1.10
# [1645 | 1200.52] loss=0.76 avg=1.10
# [1646 | 1202.15] loss=1.08 avg=1.10
# [1647 | 1203.78] loss=1.20 avg=1.10
# [1648 | 1205.41] loss=1.76 avg=1.11
# [1649 | 1207.04] loss=0.48 avg=1.10
# [1650 | 1208.67] loss=1.07 avg=1.10
# [1651 | 1210.31] loss=0.47 avg=1.09
# [1652 | 1211.93] loss=1.31 avg=1.10
# [1653 | 1213.57] loss=1.62 avg=1.10
# [1654 | 1215.20] loss=0.77 avg=1.10
# [1655 | 1216.83] loss=0.70 avg=1.09
# [1656 | 1218.46] loss=0.63 avg=1.09
# [1657 | 1220.09] loss=0.66 avg=1.09
# [1658 | 1221.73] loss=1.42 avg=1.09
# [1659 | 1223.37] loss=1.36 avg=1.09
# [1660 | 1225.00] loss=0.38 avg=1.08
# [1661 | 1226.64] loss=0.78 avg=1.08
# [1662 | 1228.27] loss=1.25 avg=1.08
# [1663 | 1229.90] loss=0.65 avg=1.08
# [1664 | 1231.53] loss=0.74 avg=1.08
# [1665 | 1233.17] loss=1.47 avg=1.08
# [1666 | 1234.80] loss=0.79 avg=1.08
# [1667 | 1236.44] loss=1.63 avg=1.08
# [1668 | 1238.08] loss=1.27 avg=1.08
# [1669 | 1239.71] loss=0.90 avg=1.08
# [1670 | 1241.34] loss=1.83 avg=1.09
# [1671 | 1242.97] loss=0.61 avg=1.08
# [1672 | 1244.61] loss=1.03 avg=1.08
# [1673 | 1246.24] loss=1.07 avg=1.08
# [1674 | 1247.87] loss=1.59 avg=1.09
# [1675 | 1249.51] loss=0.86 avg=1.09
# [1676 | 1251.14] loss=1.46 avg=1.09
# [1677 | 1252.77] loss=1.20 avg=1.09
# [1678 | 1254.39] loss=0.77 avg=1.09
# [1679 | 1256.03] loss=0.78 avg=1.09
# [1680 | 1257.66] loss=0.51 avg=1.08
# [1681 | 1259.29] loss=0.55 avg=1.07
# [1682 | 1260.92] loss=0.96 avg=1.07
# [1683 | 1262.55] loss=0.69 avg=1.07
# [1684 | 1264.19] loss=0.60 avg=1.06
# [1685 | 1265.81] loss=0.62 avg=1.06
# [1686 | 1267.45] loss=0.97 avg=1.06
# [1687 | 1269.08] loss=1.98 avg=1.07
# [1688 | 1270.71] loss=0.82 avg=1.07
# [1689 | 1272.35] loss=0.41 avg=1.06
# [1690 | 1273.98] loss=0.36 avg=1.05
# [1691 | 1275.61] loss=1.11 avg=1.05
# [1692 | 1277.24] loss=0.88 avg=1.05
# [1693 | 1278.88] loss=1.25 avg=1.05
# [1694 | 1280.51] loss=1.88 avg=1.06
# [1695 | 1282.14] loss=1.05 avg=1.06
# [1696 | 1283.78] loss=1.28 avg=1.06
# [1697 | 1285.41] loss=1.12 avg=1.06
# [1698 | 1287.04] loss=0.87 avg=1.06
# [1699 | 1288.67] loss=0.77 avg=1.06
# Generating samples...
# ======== SAMPLE 1 ========
#  had not yet made the decision to return to work once more, but the sound of voices filled the silent cave, and with trepidation I walked over to the edge of a nearby crevice.
#
# There, on the other side of a deep ravine, I found Gillyweed and Candlewick Sand, two plants which for centuries had conjured mighty storms upon magical command. Now, however, they were wilting and dying, and their wands were rustling.
#
# Something was terribly wrong here. How could this happen? The storm seemed to be weakening; my companions were emerging from the storm drains safely; the Dursleys were unhurt; what was happening to the Dursleys and the Storm Troops?
#
# Why were they wilting?
#
# And what were they dying for?
#
# ...
# [15911 | 27856.01] loss=0.07 avg=0.06
# [15912 | 27857.64] loss=0.05 avg=0.06
# [15913 | 27859.27] loss=0.15 avg=0.06
# [15914 | 27860.89] loss=0.05 avg=0.06
# [15915 | 27862.52] loss=0.03 avg=0.06
# [15916 | 27864.15] loss=0.04 avg=0.06
# [15917 | 27865.78] loss=0.06 avg=0.06
# [15918 | 27867.40] loss=0.04 avg=0.06
# [15919 | 27869.04] loss=0.05 avg=0.06
# [15920 | 27870.66] loss=0.06 avg=0.06
# [15921 | 27872.29] loss=0.05 avg=0.06
# [15922 | 27873.92] loss=0.08 avg=0.06
# [15923 | 27875.55] loss=0.08 avg=0.06
# [15924 | 27877.19] loss=0.08 avg=0.06
# [15925 | 27878.82] loss=0.04 avg=0.06
# [15926 | 27880.44] loss=0.05 avg=0.06
# [15927 | 27882.06] loss=0.06 avg=0.06
# [15928 | 27883.69] loss=0.08 avg=0.06
# [15929 | 27885.32] loss=0.07 avg=0.06
# [15930 | 27886.94] loss=0.07 avg=0.06
# [15931 | 27888.57] loss=0.04 avg=0.06
# [15932 | 27890.21] loss=0.04 avg=0.06
# [15933 | 27891.83] loss=0.07 avg=0.06
# [15934 | 27893.46] loss=0.08 avg=0.06
# [15935 | 27895.08] loss=0.06 avg=0.06
# [15936 | 27896.70] loss=0.05 avg=0.06
# [15937 | 27898.33] loss=0.06 avg=0.06
# [15938 | 27899.97] loss=0.08 avg=0.06
# [15939 | 27901.59] loss=0.05 avg=0.06
# [15940 | 27903.21] loss=0.05 avg=0.06
# [15941 | 27904.84] loss=0.03 avg=0.06
# [15942 | 27906.46] loss=0.09 avg=0.06
# [15943 | 27908.09] loss=0.04 avg=0.06
# [15944 | 27909.72] loss=0.08 avg=0.06
# [15945 | 27911.35] loss=0.06 avg=0.06
# [15946 | 27912.98] loss=0.05 avg=0.06
# [15947 | 27914.62] loss=0.04 avg=0.06
# [15948 | 27916.25] loss=0.05 avg=0.06
# [15949 | 27917.88] loss=0.05 avg=0.06
# [15950 | 27919.51] loss=0.09 avg=0.06
# [15951 | 27921.14] loss=0.07 avg=0.06
# [15952 | 27922.77] loss=0.03 avg=0.06
# [15953 | 27924.39] loss=0.07 avg=0.06
# [15954 | 27926.02] loss=0.11 avg=0.06
# [15955 | 27927.65] loss=0.08 avg=0.06
# [15956 | 27929.28] loss=0.07 avg=0.06
# [15957 | 27930.91] loss=0.06 avg=0.06
# [15958 | 27932.54] loss=0.08 avg=0.06
# [15959 | 27934.17] loss=0.04 avg=0.06
# [15960 | 27935.80] loss=0.07 avg=0.06
# [15961 | 27937.43] loss=0.05 avg=0.06
# [15962 | 27939.07] loss=0.06 avg=0.06
# [15963 | 27940.70] loss=0.04 avg=0.06
# [15964 | 27942.33] loss=0.05 avg=0.06
# [15965 | 27943.96] loss=0.07 avg=0.06
# [15966 | 27945.60] loss=0.08 avg=0.06
# [15967 | 27947.22] loss=0.04 avg=0.06
# [15968 | 27948.84] loss=0.06 avg=0.06
# [15969 | 27950.48] loss=0.05 avg=0.06
# [15970 | 27952.11] loss=0.12 avg=0.06
# [15971 | 27953.75] loss=0.03 avg=0.06
# [15972 | 27955.38] loss=0.04 avg=0.06
# [15973 | 27957.02] loss=0.05 avg=0.06
# [15974 | 27958.65] loss=0.04 avg=0.06
# [15975 | 27960.29] loss=0.06 avg=0.06
# [15976 | 27961.92] loss=0.05 avg=0.06
# [15977 | 27963.54] loss=0.07 avg=0.06
# [15978 | 27965.17] loss=0.04 avg=0.06
# [15979 | 27966.80] loss=0.04 avg=0.06
# [15980 | 27968.43] loss=0.03 avg=0.06
# [15981 | 27970.06] loss=0.06 avg=0.06
# [15982 | 27971.69] loss=0.10 avg=0.06
# [15983 | 27973.32] loss=0.06 avg=0.06
# [15984 | 27974.95] loss=0.06 avg=0.06
# [15985 | 27976.59] loss=0.07 avg=0.06
# [15986 | 27978.22] loss=0.05 avg=0.06
# [15987 | 27979.85] loss=0.08 avg=0.06
# [15988 | 27981.48] loss=0.06 avg=0.06
# [15989 | 27983.11] loss=0.03 avg=0.06
# [15990 | 27984.74] loss=0.09 avg=0.06
# [15991 | 27986.37] loss=0.05 avg=0.06
# [15992 | 27988.01] loss=0.04 avg=0.06
# [15993 | 27989.64] loss=0.08 avg=0.06
# [15994 | 27991.27] loss=0.10 avg=0.06
# [15995 | 27992.90] loss=0.06 avg=0.06
# [15996 | 27994.52] loss=0.05 avg=0.06
# [15997 | 27996.14] loss=0.08 avg=0.06
# [15998 | 27997.77] loss=0.08 avg=0.06
# [15999 | 27999.39] loss=0.08 avg=0.06
# Saving /content/drive/My Drive/Colab Notebooks/checkpoints/run1/model-16000
# Generating samples...
# ======== SAMPLE 1 ========
#
#
# He thought he saw a shimmering black shape speeding across the water, rising towards the hills, disappearing behind the rocks towards the bank. Then the shape receded below the surface, and he heard someone screaming. He turned to look at Hagrid, but he was staring at something else, a long, dark figure who was slipping and sliding through the water towards him. Harry couldn’t make out what it was, but when it did appear, Harry dipped his quill inside the water, halfway, and wrote ‘Be on the watch!’ upon the chitinous head of Eeyore, signalling her to come on board.
#
# She came right up to the surface, having first-aid training, and started splashing about in the emerald green water. Very soon, she was scrubbing on a washed-down Ton-Tongue Ankh, a quill that was supposed to make her twinge with guilt.
#
# ‘They’re dead!’ she screamed, pointing at the gigantic squid Ursula, which was snorkelling beside the bank. ‘They’re not dead!’
#
# ‘Never say never!’ shouted Hermione angrily. ‘If she’s going to the trouble to come up here and do her Ankh-Tongue, she’s going to do it really well!’
#
# She swam off to join Ron and Harry, and the others, who were busy making fire, shivered in the cold morning.
#
# ‘Feeling all right, Harry?’ said Ron, lighting a quick potion of Firebolt Oil, and handing it to Harry. ‘An odd jolt, hasn’t it? Didn’t feel like being under the weather.’
#
# ‘A bit chilly,’ Harry said, his eyes still running over the Spotted Fever to make sure Nagini hadn’t returned. ‘Miss me a bit while you get used to it?’
#
# ‘Oh, I’m fine,’ said Hermione, with a nervous laugh. ‘Really, really fine.’
#
# ‘Harry, what’s up?’ said Ron.
#
# ‘I wasn’t feeling very well,’ Harry lied.
#
# ‘Well, you’ve had a really unpleasant day, Harry.’
#
# ‘I didn’t do anything, Ron. I was just thinking … what if Diggory or Hagrid decides they want to try out for the Triwizard Tournament? Oh, Harry, why don’t you come and join them?’
#
# ‘You lied!’ Ron hissed. ‘I’ve seen you at the World Cup, bro, you should’ve got more glory for Ireland there …’
#
# ‘I had no idea!’ said Harry, unable to stop himself smiling.
#
# ‘Well, you’re going to have some fun, Harry, and I’ll be cheering you on,’ Hermione said, grinning too. ‘I wonder what’s coming?’
#
# ‘Look,’ said Harry, who was showing them the dragons, ‘ we’re getting some good food, and there’s going to be a bit of a lull … come on, let’s get cracking …’
#
# ‘Oh, I’ll do my best, Harry,’ said Hermione, and she led them all the rest of the way up the slope, away from the dragons, out into the clear blue sky.
#
# They landed in a small enclosure; they had camped there during the day, and then taken their meals outdoors. They took their First-years Quidditch pitch tip-top, and Harry showed them the ropes so they could hoist themselves over the heads of the dragons.
#
# The atmosphere was tense; they had just joined a quadrangle race, and by the look on the faces of the crowd, they were fairly sure they had spotted the dragon they had just faced.
#
# ‘What are you guys competing against?’ said Ron, who seemed to be taking it for granted that they would all be slaughtered at once.
#
# ‘We’ve got to be careful,’ said Hermione nervously. ‘Something go wrong, and we’ll all be in trouble …’
#
# They all looked down at their cauldron, and saw a blob of some black substance shooting out of it. They stared at it, astonished, and then realized what it was.
#
# A sliver of light was glittering in the wand-tip crystal glass window. Harry sucked in a deep breath, and concentrated as he had never done before, on
#
# [16000 | 28032.95] loss=0.03 avg=0.06
# [16001 | 28034.61] loss=0.05 avg=0.06
# [16002 | 28036.25] loss=0.02 avg=0.06
# [16003 | 28037.88] loss=0.08 avg=0.06
# [16004 | 28039.52] loss=0.10 avg=0.06
# [16005 | 28041.15] loss=0.04 avg=0.06
# [16006 | 28042.77] loss=0.08 avg=0.06
# [16007 | 28044.40] loss=0.04 avg=0.06
# [16008 | 28046.04] loss=0.07 avg=0.06
# [16009 | 28047.67] loss=0.03 avg=0.06
# [16010 | 28049.30] loss=0.07 avg=0.06
# [16011 | 28050.92] loss=0.09 avg=0.06
# [16012 | 28052.56] loss=0.05 avg=0.06
# [16013 | 28054.18] loss=0.03 avg=0.06
# [16014 | 28055.82] loss=0.06 avg=0.06
# [16015 | 28057.45] loss=0.06 avg=0.06
# [16016 | 28059.08] loss=0.05 avg=0.06
# [16017 | 28060.72] loss=0.08 avg=0.06
# [16018 | 28062.35] loss=0.07 avg=0.06
# [16019 | 28063.98] loss=0.06 avg=0.06
# [16020 | 28065.62] loss=0.06 avg=0.06
# [16021 | 28067.25] loss=0.06 avg=0.06
# [16022 | 28068.88] loss=0.06 avg=0.06
# [16023 | 28070.52] loss=0.07 avg=0.06
# [16024 | 28072.15] loss=0.06 avg=0.06
# [16025 | 28073.78] loss=0.06 avg=0.06
# [16026 | 28075.41] loss=0.04 avg=0.06
# [16027 | 28077.04] loss=0.06 avg=0.06
# [16028 | 28078.67] loss=0.05 avg=0.06
# [16029 | 28080.30] loss=0.05 avg=0.06
# [16030 | 28081.94] loss=0.09 avg=0.06
# [16031 | 28083.56] loss=0.08 avg=0.06
# [16032 | 28085.20] loss=0.04 avg=0.06
# [16033 | 28086.82] loss=0.06 avg=0.06
# [16034 | 28088.45] loss=0.06 avg=0.06
# [16035 | 28090.08] loss=0.05 avg=0.06
# [16036 | 28091.72] loss=0.07 avg=0.06
# [16037 | 28093.35] loss=0.06 avg=0.06
# [16038 | 28094.99] loss=0.07 avg=0.06
# [16039 | 28096.63] loss=0.05 avg=0.06
# [16040 | 28098.26] loss=0.11 avg=0.06
# [16041 | 28099.90] loss=0.10 avg=0.06
# [16042 | 28101.54] loss=0.06 avg=0.06
# [16043 | 28103.17] loss=0.09 avg=0.06
# [16044 | 28104.80] loss=0.10 avg=0.06
# [16045 | 28106.43] loss=0.05 avg=0.06
# [16046 | 28108.05] loss=0.04 avg=0.06
# [16047 | 28109.69] loss=0.05 avg=0.06
# [16048 | 28111.33] loss=0.03 avg=0.06
# [16049 | 28112.97] loss=0.04 avg=0.06
# [16050 | 28114.60] loss=0.05 avg=0.06
# [16051 | 28116.24] loss=0.04 avg=0.06
# [16052 | 28117.87] loss=0.07 avg=0.06
# [16053 | 28119.50] loss=0.04 avg=0.06
# [16054 | 28121.13] loss=0.03 avg=0.06
# [16055 | 28122.76] loss=0.03 avg=0.06
# [16056 | 28124.40] loss=0.05 avg=0.06
# [16057 | 28126.03] loss=0.07 avg=0.06
# [16058 | 28127.66] loss=0.06 avg=0.06
# [16059 | 28129.29] loss=0.03 avg=0.06
# [16060 | 28130.93] loss=0.09 avg=0.06
# [16061 | 28132.57] loss=0.04 avg=0.06
# [16062 | 28134.20] loss=0.06 avg=0.06
# [16063 | 28135.83] loss=0.04 avg=0.06
# [16064 | 28137.45] loss=0.05 avg=0.06
# [16065 | 28139.09] loss=0.09 avg=0.06
# [16066 | 28140.73] loss=0.07 avg=0.06
# [16067 | 28142.36] loss=0.06 avg=0.06
# [16068 | 28143.98] loss=0.03 avg=0.06
# [16069 | 28145.62] loss=0.06 avg=0.06
# [16070 | 28147.26] loss=0.08 avg=0.06
# [16071 | 28148.89] loss=0.05 avg=0.06
# [16072 | 28150.53] loss=0.06 avg=0.06
# [16073 | 28152.16] loss=0.04 avg=0.06
# [16074 | 28153.80] loss=0.03 avg=0.06
# [16075 | 28155.43] loss=0.03 avg=0.06
# [16076 | 28157.06] loss=0.04 avg=0.06
# [16077 | 28158.70] loss=0.07 avg=0.06
# [16078 | 28160.33] loss=0.04 avg=0.06
# [16079 | 28161.97] loss=0.05 avg=0.06
# [16080 | 28163.60] loss=0.07 avg=0.06
# [16081 | 28165.24] loss=0.08 avg=0.06
# [16082 | 28166.88] loss=0.06 avg=0.06
# [16083 | 28168.51] loss=0.03 avg=0.06
# [16084 | 28170.15] loss=0.04 avg=0.06
# [16085 | 28171.78] loss=0.04 avg=0.06
# [16086 | 28173.42] loss=0.04 avg=0.06
# [16087 | 28175.04] loss=0.07 avg=0.06
# [16088 | 28176.67] loss=0.04 avg=0.06
# [16089 | 28178.29] loss=0.06 avg=0.06
# [16090 | 28179.93] loss=0.04 avg=0.06
# [16091 | 28181.56] loss=0.07 avg=0.06
# [16092 | 28183.20] loss=0.07 avg=0.06
# [16093 | 28184.83] loss=0.05 avg=0.06
# [16094 | 28186.46] loss=0.05 avg=0.06
# [16095 | 28188.09] loss=0.05 avg=0.06
# [16096 | 28189.71] loss=0.07 avg=0.06
# [16097 | 28191.35] loss=0.10 avg=0.06
# [16098 | 28192.99] loss=0.04 avg=0.06
# [16099 | 28194.63] loss=0.04 avg=0.06
# Generating samples...
# ======== SAMPLE 1 ========
# , but his father pointed and smirked.
#
# Harry didn’t say anything. Other people might have done the same, but he didn’t want Ron to overhear … he did, however, want to finish this book as quickly as possible, so that he could send it to Sirius.
#
# ‘Great,’ he said, pounding his fist on the desk, reading the words out loud to himself. ‘Can we end this in a giantess? Because I don’t think there’s another giant with which to do –’
#
# He paused.
#
# ‘– and she cried … and she was very angry … and she came toward him … and he called her by the name he had no … ’Ouch!’
#
# ‘And the giantess fled, turning quickly to hide … but the charred remnants of the oak were all that was left of the room. Bits of the ceiling and the wall remained as white as snow …
#
# ‘The giantess had tried to kill him, didn’t she? Isn’t that right?’ said Ron.
#
# ‘Yes,’ said Harry, sitting down next to Ron and watching the white ceiling with the flames licking its face. ‘She’s tired of hearing about people like – like me.’
#
# ‘I think she’ll come visit you somewhere, Harry,’ said Ron.
#
# ‘Yeah, but she’s already here,’ said Harry, still sitting down next to Ron. ‘She’s staying in the library tonight.’
#
# ‘Oh, for heaven’s sake,’ said Ron, looking disgusted. ‘I’m trying to think who this woman is who keeps complaining about – about – about giants.’
#
# Harry laughed softly.
#
# ‘Don’t call me that!’ Ron hissed back. ‘That’s exactly what she’s been calling me ever since she heard me say I’d like to try out for the Tournament. Call me whatever you like, Ms Potter, but know that I have been diligent in finding a place for me and my family over the last few years.’
#
# ‘I don’t believe it,’ said Harry, once his wand had turned a deep, violetish blue. ‘I don’t know what’s going on, but I definitely don’t have a family to look after anymore!’
#
# Ron clapped along with Harry, but before Harry could say anything else, Hermione had Rushimo under her arm.
#
# ‘Look like you’ve got to go and look for places to live with us, now,’ she said. ‘We’ve got lots to do, and lots to see and do. Plenty of space, too, if you ask us. See you later.’
#
# She strode over to the nearest table, and Harry watched her pull a few bills out of her pocket and push them into his.
#
# ‘You owe us,’ Harry said, and he knew he ought to get ready to fight the Final Decision, but he didn’t want Hermione to think he was about to sign up for the Tournament.
#
# ‘Let me see your Wands, please,’ she said, pushing a small green-and-gold wand into his hands.
#
# ‘There are other things to worry about,’ said Harry, pushing away his own wand, which was vibrating erratically, and which had suddenly made a huge noise behind his head – it was a Portkey, sent from Godric’s Hollow by aidan banishing him).
#
# He and Hermione turned to look at it – and a huge, misty, starry-spotted sky floated into view, stretching for hundreds of yards around the mouth of the tent, through which they could see the top hat stands of the striking suits, and the finish of the Quidditch pitch. Aidan and Bagman were waiting for him outside the tent. He was wearing his finest shirt, with its buttons tied at the front, and his knife unsliced.
#
# ‘Sirius?’ he said, a little apprehensively.
#
# ‘Here, Harry,’ said Hermione, holding up a hand, ‘take this.’
#
# Harry took the handbag, which was packed with shirts, and made his way over to the man who had sent it, through the gate into the campsite. He pulled open the door, and it flew open.
#
# ‘Avada Kedavra!’ Harry shouted, and the metal tongue plunged into his mouth, spraying whatever white powder was in there –
#
# [16100 | 28218.46] loss=0.04 avg=0.06
# [16101 | 28220.09] loss=0.04 avg=0.06
# [16102 | 28221.72] loss=0.03 avg=0.06
# [16103 | 28223.35] loss=0.05 avg=0.06
# [16104 | 28224.97] loss=0.07 avg=0.06
# [16105 | 28226.59] loss=0.07 avg=0.06
# [16106 | 28228.21] loss=0.07 avg=0.06
# [16107 | 28229.83] loss=0.05 avg=0.06
# [16108 | 28231.46] loss=0.07 avg=0.06
# [16109 | 28233.09] loss=0.06 avg=0.06
# [16110 | 28234.72] loss=0.05 avg=0.06
# [16111 | 28236.35] loss=0.05 avg=0.06
# [16112 | 28237.98] loss=0.05 avg=0.06
# [16113 | 28239.61] loss=0.10 avg=0.06
# [16114 | 28241.24] loss=0.08 avg=0.06
# [16115 | 28242.86] loss=0.05 avg=0.06
# [16116 | 28244.48] loss=0.05 avg=0.06
# [16117 | 28246.11] loss=0.04 avg=0.06
# [16118 | 28247.74] loss=0.05 avg=0.06
# [16119 | 28249.37] loss=0.06 avg=0.06
# [16120 | 28250.99] loss=0.06 avg=0.06
# [16121 | 28252.60] loss=0.05 avg=0.06
# [16122 | 28254.24] loss=0.04 avg=0.06
# [16123 | 28255.87] loss=0.06 avg=0.06
# [16124 | 28257.50] loss=0.11 avg=0.06
# [16125 | 28259.13] loss=0.07 avg=0.06
# [16126 | 28260.76] loss=0.02 avg=0.06
# [16127 | 28262.40] loss=0.07 avg=0.06
# [16128 | 28264.03] loss=0.11 avg=0.06
# [16129 | 28265.65] loss=0.04 avg=0.06
# [16130 | 28267.28] loss=0.06 avg=0.06
# [16131 | 28268.91] loss=0.04 avg=0.06
# [16132 | 28270.54] loss=0.06 avg=0.06
# [16133 | 28272.17] loss=0.07 avg=0.06
# [16134 | 28273.80] loss=0.05 avg=0.06
# [16135 | 28275.43] loss=0.05 avg=0.06
# [16136 | 28277.06] loss=0.06 avg=0.06
# [16137 | 28278.69] loss=0.08 avg=0.06
# [16138 | 28280.33] loss=0.08 avg=0.06
# [16139 | 28281.97] loss=0.06 avg=0.06
# [16140 | 28283.61] loss=0.05 avg=0.06

# %% [markdown]
# ### Copiar el modelo tuneado al directorio apropiado

# %%
command = "cp -r '" + checkpoint_dir + "/.' gpt-2/models/345M/"
# !{command}

# %% [markdown]
# ### Generar muestras con el modelo

# %%
ejemplo = 'CHAPTER 1 - The Return of Voldermort' #@param {type : 'string'}
numero_de_muestras = 3 #@param {type : 'number'}
temperature=1 #@param {type : 'number'}
#@markdown La temperatura controla el grado de aleatoriedad (0 = determinista)
top_k=40 #@param {type : 'integer'}
#@markdown Número de tokens generados en cada paso. Cuanto mayor, más diverso (0 = sin restricciones, funciona bien con 40)
top_p=0.9 #@param {type : 'number'}
#@markdown Controla la diversidad. (0 = valor por defecto, funciona bien con 0.9)
texts = interact_model(prompt=ejemplo,
                       model_name='345M',
                       nsamples=numero_de_muestras,
                       temperature=temperature,
                       top_k=top_k,
                       top_p=top_p)
for i, text in enumerate(texts):
    display(HTML('<p>' + "=" * 40 + " SAMPLE " + str(i+1) + " " + "=" * 40 + '</p>'))
    display(HTML('<p>' + ('<b><i>' + ejemplo + '</b></i>' + text).replace('\n', '<br>') + '</p>'))
    display(HTML('<p>' + "=" * 80 + '</p>'))
    display(HTML('<p><br></p>'))
# Out:
# <p>======================================== SAMPLE 1 ========================================</p>
# <p><b><i>CHAPTER 1 - The Return of Voldermort</b></i><br><br>Harry felt himself being pulled uneasily forwards into a loud, echoing, ever-shifting murmur. Beyond him, the roofs of the nearby parks cracked and echoed with thunderous yells and footsteps. Death Eaters were emerging from the darkness, taking aim … Dumbledore was here … he was alive … he was kicking … he was trying to save his master …<br><br>The discharge made Harry jump. He and Cedric made a run for it; he heard Voldemort screaming, but he didn’t swing to save himself; he fell, hard, onto the ground; the Death Eaters laughed and leered at him.<br><br>For a moment, Harry just stood there, looking at the Death Eaters, then, with a mad, incoherent wave of his wand, a small piece of parchment flew out of the Death Eaters’ palms, and shaped her into a woman.<br><br>*<br><br>It was a girl … yet she was very much like his father. The dark circles under her eyes were suddenly illuminated; she had a shiny, whitish hair that was fluttering in the breeze; she was changing into a small round-table atmosphere, and she walked up and down talking to everyone in the room. Her robes were much more delicate than those of her father’s – perhaps they were because she had been so long in the thick of it – and she took much longer to draw her first few sentences.<br><br>‘ … and I have no wish to die on my own terms, nor do I care very much for the rules which prevent me doing so. I will die swinging from my chair, ready and willing to use the last of my might to restore order to a system which I see is full of murderers and thugs. I see no difference between me and the giants. I look around me and see only criminals.’<br><br>There was a very tense moment’s silence, during which Mr Weasley peered over Harry’s shoulder repeatedly. Then, very hastily, Mr Weasley said, ‘All right, Harry?’<br><br>‘Yeah,’ said Harry, anyway.<br><br>‘You know, though, that this might be a bit much for you … you have been through a lot to get here.’<br><br>‘What?’ said Harry. ‘I’m not asking you to join …’<br><br>‘No, Harry,’ said Mr Weasley, more urgently.</p>
# <p>================================================================================</p>
# <p><br></p>
# <p>======================================== SAMPLE 2 ========================================</p>
# <p><b><i>CHAPTER 1 - The Return of Voldermort</b></i><br><br>Tiny and shifty, Voldermort stalked along the edge of the enclosure, his long fingers clamped tightly upon Harry’s hip. Every now and then, he would scrape his chin with his long nails and curl up, but in the past he had attacked Harry in conversation. Now he was crouched at the foot of the tree, his arms folded, his heavily bandaged hand on Harry’s hip, his tongue lolling around in his mouth, he looked slightly nauseous, but otherwise sane. Harry had few unanswered questions, but rather as many as he would ask, after a particularly painful lesson.<br><br>‘Where were you the night I threw away my Quidditch robes?’ he said, when Harry had explained the reason for his abrupt return to the castle. ‘The Slytherins saw me in the common room after the first task. They said I had disgraced the name of the champion.’<br><br>‘Ah, but you didn’t,’ said Harry. ‘You could have made a good Parselmouth.’<br><br>Voldemort chuckled again. ‘You are not a very good Parselmouth, Karkaroff … but you were very good, in fact,’ he said dismissively, looking down at Krum’s limp body, which lay scattered around the edge of the golden boat, and which, it seemed, had been prepared for this occasion. ‘I was afraid some of my less noble supporters would react badly with my return to the fold. I was right, indeed. Some feared that my return would be premature. I was attacked for daring to return to the fold after so long associating with it. I was threatened with arrest if I went outside it. Others wanted to see me punished more severely. I understood their motives, of course … I was interested only in punishing those who had once chosen me.’<br><br>Voldemort raised his wand, and pointed it at Krum. ‘Crucio, my Lord.’<br><br>Krum struggled for breath. Voldemort smiled as one who had watched a hundred kills listlessly glide by on his desk, and who now saw his own bare chest beginning to swim in glowing red sparks as it soared over the water to the basin.<br><br>He was screaming. The shrapnel in his face was echoing off the waterfall. He was cursing. Voldemort was yelling, ‘Crucify</p>
# <p>================================================================================</p>
# <p><br></p>
# <p>======================================== SAMPLE 3 ========================================</p>
# <p><b><i>CHAPTER 1 - The Return of Voldermort</b></i><br><br>The déjà vu felt strangely vivid, as though it had been the most unreal period of his life. He had been through worse; worse than this. The Gryffindor table was crowded and noisy; Malfoy spiked wine bottles had been flying everywhere; Hermione had almost thrown her pestle pouch to the floor; Mr Weasley had almost thrown his vegetable bundle to the ground; Mrs Weasley had almost thrown her first-aid bag; a punctured Humpty Dumpty onto the ground; Mrs Weasley had resorted to using the Herbology Tower to put out the fire. In the middle of the banquet, Harry sat down with them all again, and sat next to Ron. He couldn’t believe he had ever been this uncomfortable around Ron, the person he had become so attached to almost as soon as they had left the castle. The tension in the air was more than he could stand. Hermione was nervously avoiding his eyes; Harry was itching to pry into her very soul.<br><br>‘I’ve got to go and look for people who can’t use their voices above the ground,’ Harry said, settling himself down next to Ron. ‘Er – if you could tell us what’s happening at the Ministry, Ron, if you could tell us …’<br><br>‘Hmm,’ said Ron, looking thoughtful.<br><br>‘Yeah, anything that’ll help,’ said Harry, gesturing at his scar. ‘I’ve been wanting to tell them for ages, but … well, they’re not supposed to know … you’d have thought I was there just to watch them throw things around.’<br><br>‘Well, they probably are, aren’t they?’ said Ron. ‘I mean, they’re very popular, aren’t they? There’s a certain amount of cruelty they seem to take for granted …’<br><br>‘I suppose there are,’ said Harry, picking up his Comed-Tea canister and pouring a cup himself. ‘But … well, they’re very difficult to set straight, and if they start acting suspiciously again … well … who knows, maybe they’re lying.’<br><br>‘I wouldn’t be worried about that,’ said Ron, looking uneasy. ‘I’ve never been one to trust people I didn</p>
# <p>================================================================================</p>
# <p><br></p>
